# %% [markdown]
# # Calculate Percentiles

# %%
import json, jupyterImport
jupyterImport.enableJupyterImports()
from Utilities import find, genSamples, genSample, pluck, copyKeys, allWith, finalWrite
from merge_scrapes import comments, reports, offerings, groupReplace
# Out:
# importing Jupyter notebook from Utilities.ipynb
# importing Jupyter notebook from merge_scrapes.ipynb
# importing Jupyter notebook from parse_q.ipynb
# importing Jupyter notebook from q_map.ipynb
# importing Jupyter notebook from Utilities.ipynb
# importing Jupyter notebook from my_harvard_map.ipynb
# importing Jupyter notebook from load_raw_data.ipynb

# %% [markdown]
# We'll have percentiles for each course's similar courses (department + size), `primaryDepartment` and all other `departments`, its size class, and across all courses. We'll need to compile these lists of numbers first, starting with the department ones.
#
# We use both primary departments that map directly to a group (Economics -> ECON) and bigger ones like General Education. To do this we build up a dictionary that maps departments to reports within them.

# %% [markdown]
# First issue: Q reports don't know their department, just their group. We'll take care of that with `deptNamesByGroup`.

# %%
def deptNamesByGroup(offerings, names={}):
  for offering, dept in allWith('primaryDepartment', offerings):
    names[offering['group']] = dept
  return names

# %% [markdown]
#  Now we map every Q report to the primary department that corresponds to its `group`.

# %%
from collections import defaultdict
def reportsByDept(deptNamesByGroup, reports):
  reportsByDept = defaultdict(dict)
  groups = {}
  for report, group in allWith('group', reports):
    group = groupReplace.sub(report['group'])
    groups[group] = True
    if group in deptNamesByGroup:
      reportsByDept[deptNamesByGroup[group]][report['reportId']] = report
  return reportsByDept

# %% [markdown]
# Reports don't know which departments they're in. But offerings do:

# %%
def addOfferingReportDeptNames(offerings, reportsByDept):
  for offering, topReport in allWith('topReport', offerings):
    if 'reports' in offering:
      reports = [topReport] + offering['reports']
    else:
      reports = [topReport]
    for dept in offering['departments']:
      for report in [r for r in reports if r['reportId'] not in reportsByDept[dept]]:
        reportsByDept[dept][report['reportId']] = report

# %% [markdown]
# Now we sort each of these lists of reports by `size`:

# %%
from operator import itemgetter
def deptNamesListSortedBySize(reportsByDept):
  repListByDept = {}
  for dept, repDict in reportsByDept.iteritems():
    repListByDept[dept] = sorted(repDict.values(), key=itemgetter('size'))
  return repListByDept

# %%
reportsByDepartment = reportsByDept(deptNamesByGroup(offerings), reports)
addOfferingReportDeptNames(offerings, reportsByDepartment)
reportsByDepartment = deptNamesListSortedBySize(reportsByDepartment)

# %% [markdown]
# Now we'll build up percentile lists based on the number of enrollments:

# %%
def sizeClass(size):
  size = int(size)
  if size >= 200:
    return '200+'
  elif size >= 100:
      return '100-199'
  elif size >= 40:
      return '40-99'
  elif size >= 20:
      return '20-39'
  elif size >= 10:
      return '10-19'
  elif size > 5:
      return '6-9'
  else:
      return '1-5'

def repListBySize(reports):    
  bySize = defaultdict(list)
  for report in reports:
    bySize[sizeClass(report['size'])].append(report)
  return bySize

# %%
reportsBySize = repListBySize(reports)

# %% [markdown]
# The last list we'll need is the main percentile: "similar courses." If we have a report for COMPSCI 50, we'll find the 50 most relevant Q reports as determined below. The formula considers size, title, group, number of professors, and workload.

# %%
### Takes ~30 seconds
similarReportsByReportId = genSimilarReportsByReportId(offerings)

# %% [markdown]
# We'll need to find percentiles for each attribute in `responses`, as well as the standard attributes in `profs/[]/responses`. We do this with binary search, essentially. For each list of reports we've generated (by size, department, etc.), and for each attribute (overall, workload, etc.), we'll create a sorted list of those values to search through.

# %%
profResponseQs = ['lectures', 'instructor', 'enthusiasm', 'turnaround', 'feedback', 'discussion', 'accessible']
offeringResponseQs = ['feedback', 'section', 'recommend', 'assignments', 'overall', 'workload', 'materials']

# %%
def sortedFor(keyPath, reportLists):
  sortedForKeyPath = {}
  for category, reports in reportLists:
    if '[]' in keyPath:
      keyPathValues = []
      for report, _ in allWith('profs', reports):
        for value in find(keyPath, obj=report, cast=float):
          keyPathValues.append(value)
      sortedByKeyPathValue = sorted(keyPathValues)
    else:
      sortedByKeyPathValue = sorted([find(keyPath, obj=r, cast=float) for r in reports])
    sortedForKeyPath[category] = [n for n in sortedByKeyPathValue if n]
  return sortedForKeyPath

def preSortPercentiles(reportLists, printProgress=False):
  sortedReportLists = {}
  for attribute in offeringResponseQs:
    sortedReportLists[attribute] = sortedFor('responses/' + attribute + '/score', reportLists)
    if printProgress:
      print 'Done sorting for attribute', attribute
  for attribute in profResponseQs:
    sortedReportLists[attribute] = sortedFor('profs/[]/responses/' + attribute + '/score', reportLists)
    if printProgress:
      print 'Done sorting for attribute', attribute
  return sortedReportLists

# %%
### This takes ~30 seconds, change printProgress to 'True' to see progress
reportLists = []
for repList in [reportsBySize, reportsByDepartment]:
  for category, reports in repList.items():
    reportLists.append((category, reports))
reportLists.append(('all', reports))
sortedScoreLists = preSortPercentiles(reportLists, printProgress=True)
# Out:
# Done sorting for attribute feedback
# Done sorting for attribute section
# Done sorting for attribute recommend
# Done sorting for attribute assignments
# Done sorting for attribute overall
# Done sorting for attribute workload
# Done sorting for attribute materials
# Done sorting for attribute lectures
# Done sorting for attribute instructor
# Done sorting for attribute enthusiasm
# Done sorting for attribute turnaround
# Done sorting for attribute feedback
# Done sorting for attribute discussion
# Done sorting for attribute accessible

# %% [markdown]
# Now that we've got these lists all pre-sorted, we can use them to quickly calculate percentiles, and to fit the distributions we'll use to display instead of sending down all of this data to the client like we used to. First are the percentiles:

# %%
def addPercentiles(report, offering):
  offeringAttributes = [(a, 'responses/' + a) for a in offeringResponseQs]
  profAttributes = lambda numProfs: [(a, 'profs/[' + str(i) + ']/responses/' + a) for i in range(0, numProfs) for a in profResponseQs]
  attributes = offeringAttributes + profAttributes(len(report['profs'])) if 'profs' in report else offeringAttributes
  for attribute, keyPath in attributes:
    score = find(keyPath + '/score', obj=report, cast=float)
    numLists = sortedScoreLists[attribute]
    if score:
      percentiles = {
        'size': percentileOfValue(score, numLists[sizeClass(report['size'])]),
        'all': percentileOfValue(score, numLists['all']),
#         'similar': percentileOfValue(score, numLists[report['reportId']])
      }
      for dept in [offering['primaryDepartment']] + offering['departments']:
        percentiles[dept] = percentileOfValue(score, numLists[dept])
      find(keyPath + '/percentiles', obj=report, writeVal=percentiles)
      
def calculatePercentiles():
  for offering, topReport in allWith('topReport', offerings):
    addPercentiles(topReport, offering)
    if 'reports' in offering:
      for report in offering['reports']:
        addPercentiles(report, offering)

# %%
calculatePercentiles()
offeringsWithPercentiles = offerings

# %%
### Run to inspect
similarSum = 0
similarCount = 0
for offering, _reports in genSamples(allWith('reports', offerings), 1000, includeIndices=False):
  for report, responses in allWith('responses', _reports):
    for response, percentiles in allWith('percentiles', responses.values()):
      if 'similar' in percentiles:
        similarSum += percentiles['similar']
        similarCount += 1
    print report['group'], report['number'], report['title'], 'id:', report['reportId']
    print json.dumps(responses, indent=2)
    break
# Out:
# WOMGEN 98F Tutorial - Junior Year id: 40347
# {
#   "workload": {
#     "score": "8.50",
#     "percentiles": {
#       "all": 88,
#       "Women, Gender and Sexuality": 91,
#       "size": 78
#     }
#   },
#   "feedback": {
#     "score": "2.00",
#     "percentiles": {
#       "all": 0,
#       "Women, Gender and Sexuality": 0,
#       "size": 1
#     }
#   },
#   "section": {
#     "score": "2.00",
#     "percentiles": {
#       "all": 0,
#       "Women, Gender and Sexuality": 1,
#       "size": 1
#     }
#   },
#   "overall": {
#     "score": "3.00",
#     "percentiles": {
#       "all": 0,
#       "Women, Gender and Sexuality": 1,
#       "size": 2
#     }
#   },
#   "assignments": {
#     "score": "2.50",
#     "percentiles": {
#       "all": 0,
#       "Women, Gender and Sexuality": 0,
#       "size": 1
#     }
#   },
#   "materials": {
#     "score": "3.50",
#     "percentiles": {
#       "all": 0,
#       "Women, Gender and Sexuality": 3,
#       "size": 8
#     }
#   },
#   "recommend": {
#     "score": "3.00",
#     "percentiles": {
#       "all": 0,
#       "Women, Gender and Sexuality": 1,
#       "size": 2
#     }
#   }
# }
# COMPSCI 265 Big Data Systems id: 39452
# {
#   "workload": {
#     "score": "8.21",
#     "percentiles": {
#       "all": 88,
#       "Computer Science": 43,
#       "size": 83
#     }
#   },
#   "feedback": {
#     "score": "4.31",
#     "percentiles": {
#       "all": 44,
#       "Computer Science": 67,
#       "size": 45
#     }
#   },
#   "section": {
#     "score": "4.58",
#     "percentiles": {
#       "all": 77,
#       "Computer Science": 80,
#       "size": 57
#     }
#   },
#   "overall": {
#     "score": "4.47",
#     "percentiles": {
#       "all": 77,
#       "Computer Science": 73,
#       "size": 61
#     }
#   },
#   "assignments": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "Computer Science": 84,
#       "size": 74
#     }
#   },
#   "materials": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "Computer Science": 78,
#       "size": 66
#     }
#   },
#   "recommend": {
#     "score": "4.53",
#     "percentiles": {
#       "all": 77,
#       "Computer Science": 79,
#       "size": 63
#     }
#   }
# }
# ASTRON 300 Topics in Modern Astrophysics id: 44771
# {
#   "workload": {
#     "score": "10.50",
#     "percentiles": {
#       "all": 88,
#       "Astronomy": 78,
#       "size": 94
#     }
#   },
#   "feedback": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Astronomy": 88,
#       "size": 97
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Astronomy": 84,
#       "size": 99
#     }
#   },
#   "overall": {
#     "score": "4.86",
#     "percentiles": {
#       "all": 88,
#       "Astronomy": 83,
#       "size": 99
#     }
#   },
#   "assignments": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 61,
#       "Astronomy": 44,
#       "size": 59
#     }
#   },
#   "materials": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 44,
#       "Astronomy": 41,
#       "size": 46
#     }
#   },
#   "recommend": {
#     "score": "4.83",
#     "percentiles": {
#       "all": 77,
#       "Astronomy": 78,
#       "size": 98
#     }
#   }
# }
# COMPLIT 103 Writing Across Cultures id: 27560
# {
#   "workload": {
#     "score": "5.92",
#     "percentiles": {
#       "all": 77,
#       "Comparative Literature": 50,
#       "size": 56
#     }
#   },
#   "feedback": {
#     "score": "3.92",
#     "percentiles": {
#       "all": 0,
#       "Comparative Literature": 21,
#       "size": 24
#     }
#   },
#   "section": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "Comparative Literature": 65,
#       "size": 52
#     }
#   },
#   "overall": {
#     "score": "4.08",
#     "percentiles": {
#       "all": 77,
#       "Comparative Literature": 54,
#       "size": 32
#     }
#   },
#   "assignments": {
#     "score": "4.33",
#     "percentiles": {
#       "all": 77,
#       "Comparative Literature": 65,
#       "size": 59
#     }
#   },
#   "materials": {
#     "score": "4.42",
#     "percentiles": {
#       "all": 77,
#       "Comparative Literature": 54,
#       "size": 58
#     }
#   },
#   "recommend": {
#     "score": "4.25",
#     "percentiles": {
#       "all": 66,
#       "Comparative Literature": 58,
#       "size": 40
#     }
#   }
# }
# AFRAMER 10 Introduction to African American Studies id: 37087
# {
#   "workload": {
#     "score": "4.07",
#     "percentiles": {
#       "all": 66,
#       "Sociology": 23,
#       "African and African American Studies": 40,
#       "English": 9,
#       "Ethnicity, Migration, Rights": 37,
#       "General Education": 19,
#       "size": 29
#     }
#   },
#   "feedback": {
#     "score": "3.83",
#     "percentiles": {
#       "all": 0,
#       "Sociology": 28,
#       "African and African American Studies": 28,
#       "English": 11,
#       "Ethnicity, Migration, Rights": 25,
#       "General Education": 34,
#       "size": 35
#     }
#   },
#   "section": {
#     "score": "4.32",
#     "percentiles": {
#       "all": 77,
#       "Sociology": 53,
#       "African and African American Studies": 41,
#       "English": 32,
#       "Ethnicity, Migration, Rights": 53,
#       "General Education": 81,
#       "size": 81
#     }
#   },
#   "overall": {
#     "score": "3.93",
#     "percentiles": {
#       "all": 55,
#       "Sociology": 34,
#       "African and African American Studies": 25,
#       "English": 14,
#       "Ethnicity, Migration, Rights": 35,
#       "General Education": 55,
#       "size": 56
#     }
#   },
#   "assignments": {
#     "score": "3.80",
#     "percentiles": {
#       "all": 5,
#       "Sociology": 29,
#       "African and African American Studies": 26,
#       "English": 10,
#       "Ethnicity, Migration, Rights": 29,
#       "General Education": 49,
#       "size": 53
#     }
#   },
#   "materials": {
#     "score": "4.25",
#     "percentiles": {
#       "all": 77,
#       "Sociology": 56,
#       "African and African American Studies": 49,
#       "English": 18,
#       "Ethnicity, Migration, Rights": 54,
#       "General Education": 78,
#       "size": 83
#     }
#   },
#   "recommend": {
#     "score": "4.11",
#     "percentiles": {
#       "all": 55,
#       "Sociology": 39,
#       "African and African American Studies": 28,
#       "English": 18,
#       "Ethnicity, Migration, Rights": 37,
#       "General Education": 63,
#       "size": 62
#     }
#   }
# }
# ASTRON 91R Supervised Reading and Research id: 41800
# {
#   "workload": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 66,
#       "Astronomy": 20,
#       "size": 30
#     }
#   },
#   "overall": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Astronomy": 93,
#       "size": 82
#     }
#   },
#   "recommend": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Astronomy": 92,
#       "size": 82
#     }
#   }
# }
# SCRB 175 Glucose id: 40157
# {
#   "workload": {
#     "score": "4.08",
#     "percentiles": {
#       "Stem Cell and Regenerative Biology": 32,
#       "all": 66,
#       "size": 20
#     }
#   },
#   "feedback": {
#     "score": "4.65",
#     "percentiles": {
#       "Stem Cell and Regenerative Biology": 66,
#       "all": 77,
#       "size": 76
#     }
#   },
#   "section": {
#     "score": "4.11",
#     "percentiles": {
#       "Stem Cell and Regenerative Biology": 29,
#       "all": 55,
#       "size": 44
#     }
#   },
#   "overall": {
#     "score": "4.95",
#     "percentiles": {
#       "Stem Cell and Regenerative Biology": 95,
#       "all": 88,
#       "size": 98
#     }
#   },
#   "assignments": {
#     "score": "4.65",
#     "percentiles": {
#       "Stem Cell and Regenerative Biology": 91,
#       "all": 77,
#       "size": 93
#     }
#   },
#   "materials": {
#     "score": "4.80",
#     "percentiles": {
#       "Stem Cell and Regenerative Biology": 95,
#       "all": 77,
#       "size": 95
#     }
#   },
#   "recommend": {
#     "score": "4.89",
#     "percentiles": {
#       "Stem Cell and Regenerative Biology": 87,
#       "all": 77,
#       "size": 97
#     }
#   }
# }
# HIST 1993 Introduction to Digital History id: 39929
# {
#   "workload": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 66,
#       "History": 16,
#       "size": 30
#     }
#   },
#   "feedback": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "History": 90,
#       "size": 76
#     }
#   },
#   "section": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 22,
#       "History": 27,
#       "size": 17
#     }
#   },
#   "overall": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 77,
#       "History": 24,
#       "size": 19
#     }
#   },
#   "assignments": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 61,
#       "History": 31,
#       "size": 24
#     }
#   },
#   "materials": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 44,
#       "History": 20,
#       "size": 21
#     }
#   },
#   "recommend": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 33,
#       "History": 21,
#       "size": 17
#     }
#   }
# }
# ECON 2325 Comparative Historical Economic Development id: 39520
# {
#   "workload": {
#     "score": "11.17",
#     "percentiles": {
#       "all": 88,
#       "Economics": 93,
#       "Government": 95,
#       "size": 93
#     }
#   },
#   "feedback": {
#     "score": "4.20",
#     "percentiles": {
#       "all": 44,
#       "Economics": 61,
#       "Government": 45,
#       "size": 35
#     }
#   },
#   "overall": {
#     "score": "4.80",
#     "percentiles": {
#       "all": 88,
#       "Economics": 89,
#       "Government": 89,
#       "size": 80
#     }
#   },
#   "assignments": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 61,
#       "Economics": 56,
#       "Government": 36,
#       "size": 28
#     }
#   },
#   "materials": {
#     "score": "4.20",
#     "percentiles": {
#       "all": 77,
#       "Economics": 59,
#       "Government": 44,
#       "size": 33
#     }
#   },
#   "recommend": {
#     "score": "4.80",
#     "percentiles": {
#       "all": 77,
#       "Economics": 90,
#       "Government": 88,
#       "size": 79
#     }
#   }
# }
# ENG-SCI 52 The Joy of Electronics - Part I id: 45128
# {
#   "workload": {
#     "score": "9.16",
#     "percentiles": {
#       "all": 88,
#       "Engineering Sciences": 73,
#       "size": 86
#     }
#   },
#   "feedback": {
#     "score": "3.69",
#     "percentiles": {
#       "all": 0,
#       "Engineering Sciences": 34,
#       "size": 24
#     }
#   },
#   "section": {
#     "score": "4.05",
#     "percentiles": {
#       "all": 33,
#       "Engineering Sciences": 54,
#       "size": 41
#     }
#   },
#   "overall": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 77,
#       "Engineering Sciences": 51,
#       "size": 40
#     }
#   },
#   "assignments": {
#     "score": "3.81",
#     "percentiles": {
#       "all": 22,
#       "Engineering Sciences": 50,
#       "size": 32
#     }
#   },
#   "materials": {
#     "score": "3.91",
#     "percentiles": {
#       "all": 33,
#       "Engineering Sciences": 49,
#       "size": 32
#     }
#   },
#   "recommend": {
#     "score": "4.12",
#     "percentiles": {
#       "all": 55,
#       "Engineering Sciences": 58,
#       "size": 44
#     }
#   }
# }
# LING 118 Historical and Comparative Linguistics id: 37061
# {
#   "workload": {
#     "score": "4.39",
#     "percentiles": {
#       "Linguistics": 33,
#       "all": 66,
#       "size": 28
#     }
#   },
#   "feedback": {
#     "score": "4.67",
#     "percentiles": {
#       "Linguistics": 68,
#       "all": 88,
#       "size": 69
#     }
#   },
#   "overall": {
#     "score": "3.78",
#     "percentiles": {
#       "Linguistics": 25,
#       "all": 22,
#       "size": 17
#     }
#   },
#   "assignments": {
#     "score": "4.00",
#     "percentiles": {
#       "Linguistics": 36,
#       "all": 61,
#       "size": 33
#     }
#   },
#   "materials": {
#     "score": "4.11",
#     "percentiles": {
#       "Linguistics": 46,
#       "all": 55,
#       "size": 33
#     }
#   },
#   "recommend": {
#     "score": "3.56",
#     "percentiles": {
#       "Linguistics": 11,
#       "all": 0,
#       "size": 9
#     }
#   }
# }
# MCB 99B Laboratory Research for Honors Thesis id: 45394
# {
#   "workload": {
#     "score": "16.50",
#     "percentiles": {
#       "all": 88,
#       "Molecular and Cellular Biology": 99,
#       "size": 99
#     }
#   },
#   "feedback": {
#     "score": "2.00",
#     "percentiles": {
#       "all": 0,
#       "Molecular and Cellular Biology": 1,
#       "size": 1
#     }
#   },
#   "overall": {
#     "score": "4.11",
#     "percentiles": {
#       "all": 77,
#       "Molecular and Cellular Biology": 53,
#       "size": 35
#     }
#   },
#   "assignments": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Molecular and Cellular Biology": 98,
#       "size": 98
#     }
#   },
#   "materials": {
#     "score": "3.00",
#     "percentiles": {
#       "all": 0,
#       "Molecular and Cellular Biology": 3,
#       "size": 2
#     }
#   },
#   "recommend": {
#     "score": "3.75",
#     "percentiles": {
#       "all": 0,
#       "Molecular and Cellular Biology": 29,
#       "size": 14
#     }
#   }
# }
# NEUROBIO 209 Neurobiology of Disease id: 37743
# {
#   "workload": {
#     "score": "4.50",
#     "percentiles": {
#       "Medical Sciences": 38,
#       "all": 66,
#       "Neurobiology - Graduate": 46,
#       "Neurobiology": 47,
#       "size": 30
#     }
#   },
#   "feedback": {
#     "score": "3.69",
#     "percentiles": {
#       "Medical Sciences": 29,
#       "all": 0,
#       "Neurobiology - Graduate": 22,
#       "Neurobiology": 24,
#       "size": 18
#     }
#   },
#   "section": {
#     "score": "4.50",
#     "percentiles": {
#       "Medical Sciences": 69,
#       "all": 77,
#       "Neurobiology - Graduate": 49,
#       "Neurobiology": 75,
#       "size": 52
#     }
#   },
#   "overall": {
#     "score": "4.62",
#     "percentiles": {
#       "Medical Sciences": 78,
#       "all": 77,
#       "Neurobiology - Graduate": 67,
#       "Neurobiology": 84,
#       "size": 74
#     }
#   },
#   "assignments": {
#     "score": "3.67",
#     "percentiles": {
#       "Medical Sciences": 38,
#       "all": 0,
#       "Neurobiology - Graduate": 14,
#       "Neurobiology": 30,
#       "size": 15
#     }
#   },
#   "materials": {
#     "score": "3.77",
#     "percentiles": {
#       "Medical Sciences": 36,
#       "all": 11,
#       "Neurobiology - Graduate": 15,
#       "Neurobiology": 22,
#       "size": 15
#     }
#   },
#   "recommend": {
#     "score": "4.54",
#     "percentiles": {
#       "Medical Sciences": 69,
#       "all": 77,
#       "Neurobiology - Graduate": 58,
#       "Neurobiology": 80,
#       "size": 64
#     }
#   }
# }
# HIST 92R History Lab id: 38012
# {
#   "workload": {
#     "score": "8.50",
#     "percentiles": {
#       "all": 88,
#       "History": 77,
#       "size": 78
#     }
#   },
#   "feedback": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "History": 90,
#       "size": 76
#     }
#   },
#   "overall": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "History": 94,
#       "size": 82
#     }
#   },
#   "assignments": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "History": 95,
#       "size": 85
#     }
#   },
#   "materials": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "History": 94,
#       "size": 82
#     }
#   },
#   "recommend": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "History": 94,
#       "size": 82
#     }
#   }
# }
# RELIGION 98A Tutorial - Junior Year id: 21247
# {
#   "workload": {
#     "score": "6.00",
#     "percentiles": {
#       "Religion": 58,
#       "all": 77,
#       "Religion, The Study of": 65,
#       "size": 57
#     }
#   },
#   "feedback": {
#     "score": "4.75",
#     "percentiles": {
#       "Religion": 67,
#       "all": 88,
#       "Religion, The Study of": 74,
#       "size": 76
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "Religion": 82,
#       "all": 88,
#       "Religion, The Study of": 81,
#       "size": 87
#     }
#   },
#   "overall": {
#     "score": "4.71",
#     "percentiles": {
#       "Religion": 75,
#       "all": 77,
#       "Religion, The Study of": 80,
#       "size": 81
#     }
#   },
#   "assignments": {
#     "score": "4.62",
#     "percentiles": {
#       "Religion": 72,
#       "all": 77,
#       "Religion, The Study of": 78,
#       "size": 82
#     }
#   },
#   "materials": {
#     "score": "4.38",
#     "percentiles": {
#       "Religion": 43,
#       "all": 77,
#       "Religion, The Study of": 44,
#       "size": 55
#     }
#   },
#   "recommend": {
#     "score": "4.75",
#     "percentiles": {
#       "Religion": 77,
#       "all": 77,
#       "Religion, The Study of": 80,
#       "size": 81
#     }
#   }
# }
# LING 83 Language, Structure, and Cognition id: 45336
# {
#   "workload": {
#     "score": "4.09",
#     "percentiles": {
#       "Linguistics": 28,
#       "all": 66,
#       "size": 24
#     }
#   },
#   "feedback": {
#     "score": "4.25",
#     "percentiles": {
#       "Linguistics": 44,
#       "all": 44,
#       "size": 58
#     }
#   },
#   "section": {
#     "score": "3.95",
#     "percentiles": {
#       "Linguistics": 27,
#       "all": 22,
#       "size": 42
#     }
#   },
#   "overall": {
#     "score": "4.29",
#     "percentiles": {
#       "Linguistics": 60,
#       "all": 77,
#       "size": 73
#     }
#   },
#   "assignments": {
#     "score": "3.91",
#     "percentiles": {
#       "Linguistics": 28,
#       "all": 44,
#       "size": 50
#     }
#   },
#   "materials": {
#     "score": "4.31",
#     "percentiles": {
#       "Linguistics": 62,
#       "all": 77,
#       "size": 75
#     }
#   },
#   "recommend": {
#     "score": "4.20",
#     "percentiles": {
#       "Linguistics": 51,
#       "all": 66,
#       "size": 60
#     }
#   }
# }
# FRSEMR 36J Folklore and the Culture of Childhood id: 37611
# {
#   "workload": {
#     "score": "3.86",
#     "percentiles": {
#       "Freshman Seminar": 74,
#       "all": 55,
#       "Freshman Seminars": 78,
#       "Folklore and Mythology": 39,
#       "size": 20
#     }
#   },
#   "feedback": {
#     "score": "4.45",
#     "percentiles": {
#       "Freshman Seminar": 61,
#       "all": 55,
#       "Freshman Seminars": 53,
#       "Folklore and Mythology": 48,
#       "size": 54
#     }
#   },
#   "section": {
#     "score": "4.25",
#     "percentiles": {
#       "Freshman Seminar": 35,
#       "all": 66,
#       "Freshman Seminars": 29,
#       "Folklore and Mythology": 34,
#       "size": 38
#     }
#   },
#   "overall": {
#     "score": "4.55",
#     "percentiles": {
#       "Freshman Seminar": 63,
#       "all": 77,
#       "Freshman Seminars": 53,
#       "Folklore and Mythology": 52,
#       "size": 68
#     }
#   },
#   "assignments": {
#     "score": "4.45",
#     "percentiles": {
#       "Freshman Seminar": 71,
#       "all": 77,
#       "Freshman Seminars": 59,
#       "Folklore and Mythology": 51,
#       "size": 70
#     }
#   },
#   "materials": {
#     "score": "4.55",
#     "percentiles": {
#       "Freshman Seminar": 71,
#       "all": 77,
#       "Freshman Seminars": 67,
#       "Folklore and Mythology": 60,
#       "size": 69
#     }
#   },
#   "recommend": {
#     "score": "4.73",
#     "percentiles": {
#       "Freshman Seminar": 74,
#       "all": 77,
#       "Freshman Seminars": 63,
#       "Folklore and Mythology": 63,
#       "size": 80
#     }
#   }
# }
# COMPSCI 365 SEAS Teaching Practicum id: 47083
# {
#   "workload": {
#     "score": "3.50",
#     "percentiles": {
#       "all": 44,
#       "Applied Mathematics": 8,
#       "Computer Science": 2,
#       "Applied Physics": 5,
#       "Engineering Sciences": 6,
#       "size": 14
#     }
#   },
#   "feedback": {
#     "score": "4.33",
#     "percentiles": {
#       "all": 55,
#       "Applied Mathematics": 81,
#       "Computer Science": 68,
#       "Applied Physics": 77,
#       "Engineering Sciences": 70,
#       "size": 29
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Applied Mathematics": 96,
#       "Computer Science": 92,
#       "Applied Physics": 96,
#       "Engineering Sciences": 92,
#       "size": 70
#     }
#   },
#   "overall": {
#     "score": "4.67",
#     "percentiles": {
#       "all": 77,
#       "Applied Mathematics": 94,
#       "Computer Science": 88,
#       "Applied Physics": 92,
#       "Engineering Sciences": 90,
#       "size": 54
#     }
#   },
#   "assignments": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Applied Mathematics": 98,
#       "Computer Science": 99,
#       "Applied Physics": 98,
#       "Engineering Sciences": 98,
#       "size": 85
#     }
#   },
#   "materials": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 44,
#       "Applied Mathematics": 62,
#       "Computer Science": 41,
#       "Applied Physics": 57,
#       "Engineering Sciences": 55,
#       "size": 21
#     }
#   },
#   "recommend": {
#     "score": "4.67",
#     "percentiles": {
#       "all": 77,
#       "Applied Mathematics": 94,
#       "Computer Science": 89,
#       "Applied Physics": 92,
#       "Engineering Sciences": 88,
#       "size": 53
#     }
#   }
# }
# ECON 1310 The Economy of China id: 40936
# {
#   "workload": {
#     "score": "4.10",
#     "percentiles": {
#       "all": 66,
#       "Economics": 14,
#       "size": 24
#     }
#   },
#   "feedback": {
#     "score": "2.94",
#     "percentiles": {
#       "all": 0,
#       "Economics": 10,
#       "size": 4
#     }
#   },
#   "section": {
#     "score": "3.36",
#     "percentiles": {
#       "all": 0,
#       "Economics": 22,
#       "size": 12
#     }
#   },
#   "overall": {
#     "score": "3.24",
#     "percentiles": {
#       "all": 0,
#       "Economics": 9,
#       "size": 9
#     }
#   },
#   "assignments": {
#     "score": "3.14",
#     "percentiles": {
#       "all": 0,
#       "Economics": 9,
#       "size": 6
#     }
#   },
#   "materials": {
#     "score": "3.34",
#     "percentiles": {
#       "all": 0,
#       "Economics": 12,
#       "size": 7
#     }
#   },
#   "recommend": {
#     "score": "3.13",
#     "percentiles": {
#       "all": 0,
#       "Economics": 5,
#       "size": 4
#     }
#   }
# }
# MATH 155R Combinatorics id: 41635
# {
#   "workload": {
#     "score": "5.56",
#     "percentiles": {
#       "Mathematics": 23,
#       "all": 77,
#       "size": 50
#     }
#   },
#   "feedback": {
#     "score": "3.81",
#     "percentiles": {
#       "Mathematics": 30,
#       "all": 0,
#       "size": 21
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "Mathematics": 90,
#       "all": 88,
#       "size": 87
#     }
#   },
#   "overall": {
#     "score": "4.50",
#     "percentiles": {
#       "Mathematics": 69,
#       "all": 77,
#       "size": 64
#     }
#   },
#   "assignments": {
#     "score": "4.44",
#     "percentiles": {
#       "Mathematics": 74,
#       "all": 77,
#       "size": 69
#     }
#   },
#   "materials": {
#     "score": "4.25",
#     "percentiles": {
#       "Mathematics": 56,
#       "all": 77,
#       "size": 44
#     }
#   },
#   "recommend": {
#     "score": "4.50",
#     "percentiles": {
#       "Mathematics": 74,
#       "all": 77,
#       "size": 61
#     }
#   }
# }
# RSRA 298A Master's Thesis Reading and Research id: 47765
# {
#   "workload": {
#     "score": "2.10",
#     "percentiles": {
#       "all": 0,
#       "Russia, Eastern Europe, and Central Asia": 1,
#       "size": 4
#     }
#   },
#   "feedback": {
#     "score": "4.20",
#     "percentiles": {
#       "all": 44,
#       "Russia, Eastern Europe, and Central Asia": 26,
#       "size": 35
#     }
#   },
#   "section": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 22,
#       "Russia, Eastern Europe, and Central Asia": 19,
#       "size": 21
#     }
#   },
#   "overall": {
#     "score": "3.80",
#     "percentiles": {
#       "all": 22,
#       "Russia, Eastern Europe, and Central Asia": 9,
#       "size": 15
#     }
#   },
#   "assignments": {
#     "score": "3.80",
#     "percentiles": {
#       "all": 5,
#       "Russia, Eastern Europe, and Central Asia": 11,
#       "size": 17
#     }
#   },
#   "materials": {
#     "score": "3.60",
#     "percentiles": {
#       "all": 0,
#       "Russia, Eastern Europe, and Central Asia": 7,
#       "size": 9
#     }
#   },
#   "recommend": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 33,
#       "Russia, Eastern Europe, and Central Asia": 15,
#       "size": 20
#     }
#   }
# }
# VES 60X Fiction in the Flesh id: 40327
# {
#   "workload": {
#     "score": "8.50",
#     "percentiles": {
#       "all": 88,
#       "Visual and Environmental Studies": 60,
#       "size": 84
#     }
#   },
#   "feedback": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Visual and Environmental Studies": 91,
#       "size": 93
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Visual and Environmental Studies": 73,
#       "size": 87
#     }
#   },
#   "overall": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Visual and Environmental Studies": 93,
#       "size": 97
#     }
#   },
#   "assignments": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Visual and Environmental Studies": 93,
#       "size": 98
#     }
#   },
#   "materials": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Visual and Environmental Studies": 92,
#       "size": 98
#     }
#   },
#   "recommend": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Visual and Environmental Studies": 92,
#       "size": 97
#     }
#   }
# }
# BIOSTAT 233 Methods II id: 41814
# {
#   "workload": {
#     "score": "12.23",
#     "percentiles": {
#       "all": 88,
#       "Biostatistics": 92,
#       "size": 97
#     }
#   },
#   "feedback": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 11,
#       "Biostatistics": 59,
#       "size": 29
#     }
#   },
#   "section": {
#     "score": "3.73",
#     "percentiles": {
#       "all": 0,
#       "Biostatistics": 41,
#       "size": 16
#     }
#   },
#   "overall": {
#     "score": "4.31",
#     "percentiles": {
#       "all": 77,
#       "Biostatistics": 80,
#       "size": 49
#     }
#   },
#   "assignments": {
#     "score": "3.62",
#     "percentiles": {
#       "all": 0,
#       "Biostatistics": 43,
#       "size": 14
#     }
#   },
#   "materials": {
#     "score": "4.64",
#     "percentiles": {
#       "all": 77,
#       "Biostatistics": 88,
#       "size": 78
#     }
#   },
#   "recommend": {
#     "score": "4.25",
#     "percentiles": {
#       "all": 66,
#       "Biostatistics": 69,
#       "size": 40
#     }
#   }
# }
# STAT 120 Introduction to Applied Bayesian Inference and Multilevel Models id: 40247
# {
#   "workload": {
#     "score": "7.53",
#     "percentiles": {
#       "all": 88,
#       "Statistics": 63,
#       "size": 78
#     }
#   },
#   "feedback": {
#     "score": "3.30",
#     "percentiles": {
#       "all": 0,
#       "Statistics": 4,
#       "size": 12
#     }
#   },
#   "section": {
#     "score": "4.14",
#     "percentiles": {
#       "all": 55,
#       "Statistics": 45,
#       "size": 57
#     }
#   },
#   "overall": {
#     "score": "3.23",
#     "percentiles": {
#       "all": 0,
#       "Statistics": 8,
#       "size": 8
#     }
#   },
#   "assignments": {
#     "score": "4.08",
#     "percentiles": {
#       "all": 66,
#       "Statistics": 50,
#       "size": 67
#     }
#   },
#   "materials": {
#     "score": "3.62",
#     "percentiles": {
#       "all": 0,
#       "Statistics": 14,
#       "size": 19
#     }
#   },
#   "recommend": {
#     "score": "3.52",
#     "percentiles": {
#       "all": 0,
#       "Statistics": 13,
#       "size": 13
#     }
#   }
# }
# OEB 10 Foundations of Biological Diversity id: 43834
# {
#   "workload": {
#     "score": "4.27",
#     "percentiles": {
#       "Organismic and Evolutionary Biology": 49,
#       "all": 66,
#       "General Education": 25,
#       "size": 28
#     }
#   },
#   "feedback": {
#     "score": "3.18",
#     "percentiles": {
#       "Organismic and Evolutionary Biology": 5,
#       "all": 0,
#       "General Education": 8,
#       "size": 9
#     }
#   },
#   "section": {
#     "score": "3.26",
#     "percentiles": {
#       "Organismic and Evolutionary Biology": 4,
#       "all": 0,
#       "General Education": 9,
#       "size": 9
#     }
#   },
#   "overall": {
#     "score": "3.35",
#     "percentiles": {
#       "Organismic and Evolutionary Biology": 2,
#       "all": 0,
#       "General Education": 15,
#       "size": 12
#     }
#   },
#   "assignments": {
#     "score": "3.32",
#     "percentiles": {
#       "Organismic and Evolutionary Biology": 6,
#       "all": 0,
#       "General Education": 13,
#       "size": 9
#     }
#   },
#   "materials": {
#     "score": "3.72",
#     "percentiles": {
#       "Organismic and Evolutionary Biology": 13,
#       "all": 0,
#       "General Education": 31,
#       "size": 24
#     }
#   },
#   "recommend": {
#     "score": "3.41",
#     "percentiles": {
#       "Organismic and Evolutionary Biology": 4,
#       "all": 0,
#       "General Education": 13,
#       "size": 10
#     }
#   }
# }
# ASTRON 219 High Energy Astrophysics id: 37186
# {
#   "workload": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 66,
#       "Astronomy": 20,
#       "size": 30
#     }
#   },
#   "feedback": {
#     "score": "2.00",
#     "percentiles": {
#       "all": 0,
#       "Astronomy": 5,
#       "size": 1
#     }
#   },
#   "section": {
#     "score": "1.00",
#     "percentiles": {
#       "all": 0,
#       "Astronomy": 0,
#       "size": 0
#     }
#   },
#   "overall": {
#     "score": "1.00",
#     "percentiles": {
#       "all": 0,
#       "Astronomy": 0,
#       "size": 0
#     }
#   },
#   "assignments": {
#     "score": "1.00",
#     "percentiles": {
#       "all": 0,
#       "Astronomy": 0,
#       "size": 0
#     }
#   },
#   "materials": {
#     "score": "2.00",
#     "percentiles": {
#       "all": 0,
#       "Astronomy": 0,
#       "size": 0
#     }
#   },
#   "recommend": {
#     "score": "1.00",
#     "percentiles": {
#       "all": 0,
#       "Astronomy": 0,
#       "size": 0
#     }
#   }
# }
# ENG-SCI 153 Laboratory Electronics id: 43918
# {
#   "workload": {
#     "score": "12.50",
#     "percentiles": {
#       "all": 88,
#       "General Education": 96,
#       "Engineering Sciences": 92,
#       "size": 96
#     }
#   },
#   "feedback": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 11,
#       "General Education": 45,
#       "Engineering Sciences": 53,
#       "size": 26
#     }
#   },
#   "section": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 22,
#       "General Education": 56,
#       "Engineering Sciences": 48,
#       "size": 21
#     }
#   },
#   "overall": {
#     "score": "4.33",
#     "percentiles": {
#       "all": 77,
#       "General Education": 84,
#       "Engineering Sciences": 70,
#       "size": 42
#     }
#   },
#   "assignments": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 61,
#       "General Education": 67,
#       "Engineering Sciences": 63,
#       "size": 28
#     }
#   },
#   "materials": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 44,
#       "General Education": 56,
#       "Engineering Sciences": 55,
#       "size": 22
#     }
#   },
#   "recommend": {
#     "score": "4.67",
#     "percentiles": {
#       "all": 77,
#       "General Education": 95,
#       "Engineering Sciences": 88,
#       "size": 67
#     }
#   }
# }
# SHBT 203 Anatomy of Speech and Hearing id: 41949
# {
#   "workload": {
#     "score": "12.07",
#     "percentiles": {
#       "all": 88,
#       "Speech and Hearing Sciences": 73,
#       "Medical Sciences": 92,
#       "size": 95
#     }
#   },
#   "feedback": {
#     "score": "2.83",
#     "percentiles": {
#       "all": 0,
#       "Speech and Hearing Sciences": 16,
#       "Medical Sciences": 7,
#       "size": 4
#     }
#   },
#   "section": {
#     "score": "3.50",
#     "percentiles": {
#       "all": 0,
#       "Speech and Hearing Sciences": 28,
#       "Medical Sciences": 9,
#       "size": 10
#     }
#   },
#   "overall": {
#     "score": "4.14",
#     "percentiles": {
#       "all": 77,
#       "Speech and Hearing Sciences": 65,
#       "Medical Sciences": 56,
#       "size": 29
#     }
#   },
#   "assignments": {
#     "score": "3.86",
#     "percentiles": {
#       "all": 33,
#       "Speech and Hearing Sciences": 64,
#       "Medical Sciences": 48,
#       "size": 20
#     }
#   },
#   "materials": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 44,
#       "Speech and Hearing Sciences": 54,
#       "Medical Sciences": 48,
#       "size": 22
#     }
#   },
#   "recommend": {
#     "score": "4.14",
#     "percentiles": {
#       "all": 55,
#       "Speech and Hearing Sciences": 52,
#       "Medical Sciences": 43,
#       "size": 26
#     }
#   }
# }
# CATALAN 20 Catalan Language and Culture id: 26735
# {
#   "workload": {
#     "score": "1.50",
#     "percentiles": {
#       "Catalan": 16,
#       "all": 0,
#       "Romance Languages and Literature": 0,
#       "size": 2
#     }
#   },
#   "feedback": {
#     "score": "4.50",
#     "percentiles": {
#       "Catalan": 0,
#       "all": 66,
#       "Romance Languages and Literature": 43,
#       "size": 36
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "Catalan": 60,
#       "all": 88,
#       "Romance Languages and Literature": 89,
#       "size": 70
#     }
#   },
#   "overall": {
#     "score": "5.00",
#     "percentiles": {
#       "Catalan": 66,
#       "all": 88,
#       "Romance Languages and Literature": 95,
#       "size": 82
#     }
#   },
#   "assignments": {
#     "score": "4.50",
#     "percentiles": {
#       "Catalan": 16,
#       "all": 77,
#       "Romance Languages and Literature": 79,
#       "size": 51
#     }
#   },
#   "materials": {
#     "score": "4.50",
#     "percentiles": {
#       "Catalan": 58,
#       "all": 77,
#       "Romance Languages and Literature": 73,
#       "size": 45
#     }
#   },
#   "recommend": {
#     "score": "5.00",
#     "percentiles": {
#       "Catalan": 58,
#       "all": 88,
#       "Romance Languages and Literature": 95,
#       "size": 82
#     }
#   }
# }
# ASTRON 200 Radiative Processes in Astrophysics id: 43628
# {
#   "workload": {
#     "score": "8.50",
#     "percentiles": {
#       "all": 88,
#       "Astronomy": 65,
#       "size": 84
#     }
#   },
#   "feedback": {
#     "score": "4.54",
#     "percentiles": {
#       "all": 66,
#       "Astronomy": 67,
#       "size": 60
#     }
#   },
#   "section": {
#     "score": "4.62",
#     "percentiles": {
#       "all": 77,
#       "Astronomy": 62,
#       "size": 59
#     }
#   },
#   "overall": {
#     "score": "4.77",
#     "percentiles": {
#       "all": 77,
#       "Astronomy": 80,
#       "size": 85
#     }
#   },
#   "assignments": {
#     "score": "4.15",
#     "percentiles": {
#       "all": 66,
#       "Astronomy": 52,
#       "size": 45
#     }
#   },
#   "materials": {
#     "score": "4.17",
#     "percentiles": {
#       "all": 66,
#       "Astronomy": 53,
#       "size": 37
#     }
#   },
#   "recommend": {
#     "score": "4.69",
#     "percentiles": {
#       "all": 77,
#       "Astronomy": 69,
#       "size": 77
#     }
#   }
# }
# SOCWORLD 27 The Two Koreas id: 38197
# {
#   "workload": {
#     "score": "4.45",
#     "percentiles": {
#       "all": 66,
#       "General Education": 29,
#       "East Asian Languages and Civilizations": 10,
#       "Societies of the World": 40,
#       "size": 34
#     }
#   },
#   "feedback": {
#     "score": "4.22",
#     "percentiles": {
#       "all": 44,
#       "General Education": 61,
#       "East Asian Languages and Civilizations": 13,
#       "Societies of the World": 50,
#       "size": 56
#     }
#   },
#   "section": {
#     "score": "4.34",
#     "percentiles": {
#       "all": 77,
#       "General Education": 83,
#       "East Asian Languages and Civilizations": 24,
#       "Societies of the World": 72,
#       "size": 72
#     }
#   },
#   "overall": {
#     "score": "4.44",
#     "percentiles": {
#       "all": 77,
#       "General Education": 89,
#       "East Asian Languages and Civilizations": 37,
#       "Societies of the World": 88,
#       "size": 84
#     }
#   },
#   "assignments": {
#     "score": "4.21",
#     "percentiles": {
#       "all": 77,
#       "General Education": 84,
#       "East Asian Languages and Civilizations": 34,
#       "Societies of the World": 83,
#       "size": 78
#     }
#   },
#   "materials": {
#     "score": "4.41",
#     "percentiles": {
#       "all": 77,
#       "General Education": 87,
#       "East Asian Languages and Civilizations": 40,
#       "Societies of the World": 85,
#       "size": 82
#     }
#   },
#   "recommend": {
#     "score": "4.44",
#     "percentiles": {
#       "all": 77,
#       "General Education": 87,
#       "East Asian Languages and Civilizations": 39,
#       "Societies of the World": 84,
#       "size": 79
#     }
#   }
# }
# SOCIOL 248 Race, Politics, and Social Inequality id: 33776
# {
#   "workload": {
#     "score": "6.50",
#     "percentiles": {
#       "all": 77,
#       "Sociology": 70,
#       "size": 65
#     }
#   },
#   "feedback": {
#     "score": "4.25",
#     "percentiles": {
#       "all": 44,
#       "Sociology": 54,
#       "size": 42
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Sociology": 89,
#       "size": 87
#     }
#   },
#   "overall": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Sociology": 97,
#       "size": 97
#     }
#   },
#   "assignments": {
#     "score": "4.62",
#     "percentiles": {
#       "all": 77,
#       "Sociology": 87,
#       "size": 82
#     }
#   },
#   "materials": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Sociology": 98,
#       "size": 98
#     }
#   },
#   "recommend": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Sociology": 97,
#       "size": 97
#     }
#   }
# }
# ANTHRO 1610 Ethnographic Research Methods id: 43420
# {
#   "workload": {
#     "score": "5.12",
#     "percentiles": {
#       "Anthropology": 42,
#       "African and African American Studies": 70,
#       "all": 77,
#       "size": 42
#     }
#   },
#   "feedback": {
#     "score": "3.82",
#     "percentiles": {
#       "Anthropology": 26,
#       "African and African American Studies": 28,
#       "all": 0,
#       "size": 28
#     }
#   },
#   "section": {
#     "score": "3.12",
#     "percentiles": {
#       "Anthropology": 7,
#       "African and African American Studies": 7,
#       "all": 0,
#       "size": 7
#     }
#   },
#   "overall": {
#     "score": "3.88",
#     "percentiles": {
#       "Anthropology": 28,
#       "African and African American Studies": 23,
#       "all": 55,
#       "size": 32
#     }
#   },
#   "assignments": {
#     "score": "3.88",
#     "percentiles": {
#       "Anthropology": 30,
#       "African and African American Studies": 29,
#       "all": 33,
#       "size": 38
#     }
#   },
#   "materials": {
#     "score": "3.88",
#     "percentiles": {
#       "Anthropology": 21,
#       "African and African American Studies": 27,
#       "all": 22,
#       "size": 29
#     }
#   },
#   "recommend": {
#     "score": "3.94",
#     "percentiles": {
#       "Anthropology": 25,
#       "African and African American Studies": 18,
#       "all": 22,
#       "size": 32
#     }
#   }
# }
# ENG-SCI 231 Energy Technology id: 41057
# {
#   "workload": {
#     "score": "6.00",
#     "percentiles": {
#       "all": 77,
#       "Engineering Sciences": 33,
#       "size": 57
#     }
#   },
#   "feedback": {
#     "score": "3.60",
#     "percentiles": {
#       "all": 0,
#       "Engineering Sciences": 30,
#       "size": 15
#     }
#   },
#   "section": {
#     "score": "3.50",
#     "percentiles": {
#       "all": 0,
#       "Engineering Sciences": 23,
#       "size": 11
#     }
#   },
#   "overall": {
#     "score": "3.60",
#     "percentiles": {
#       "all": 0,
#       "Engineering Sciences": 28,
#       "size": 11
#     }
#   },
#   "assignments": {
#     "score": "3.50",
#     "percentiles": {
#       "all": 0,
#       "Engineering Sciences": 28,
#       "size": 10
#     }
#   },
#   "materials": {
#     "score": "3.80",
#     "percentiles": {
#       "all": 11,
#       "Engineering Sciences": 43,
#       "size": 16
#     }
#   },
#   "recommend": {
#     "score": "3.80",
#     "percentiles": {
#       "all": 0,
#       "Engineering Sciences": 34,
#       "size": 16
#     }
#   }
# }
# FOLKMYTH 98A History and Theory of Folklore and Mythology id: 43293
# {
#   "workload": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 66,
#       "Folklore and Mythology": 63,
#       "size": 30
#     }
#   },
#   "feedback": {
#     "score": "3.67",
#     "percentiles": {
#       "all": 0,
#       "Folklore and Mythology": 13,
#       "size": 11
#     }
#   },
#   "overall": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 77,
#       "Folklore and Mythology": 25,
#       "size": 19
#     }
#   },
#   "assignments": {
#     "score": "4.67",
#     "percentiles": {
#       "all": 77,
#       "Folklore and Mythology": 70,
#       "size": 62
#     }
#   },
#   "materials": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 44,
#       "Folklore and Mythology": 22,
#       "size": 21
#     }
#   },
#   "recommend": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 33,
#       "Folklore and Mythology": 16,
#       "size": 17
#     }
#   }
# }
# GREEK 134 The Language of Homer id: 35519
# {
#   "workload": {
#     "score": "6.79",
#     "percentiles": {
#       "Greek": 33,
#       "all": 77,
#       "Classics, The": 52,
#       "size": 61
#     }
#   },
#   "feedback": {
#     "score": "4.43",
#     "percentiles": {
#       "Greek": 43,
#       "all": 55,
#       "Classics, The": 48,
#       "size": 46
#     }
#   },
#   "section": {
#     "score": "4.00",
#     "percentiles": {
#       "Greek": 10,
#       "all": 22,
#       "Classics, The": 24,
#       "size": 21
#     }
#   },
#   "overall": {
#     "score": "4.29",
#     "percentiles": {
#       "Greek": 33,
#       "all": 77,
#       "Classics, The": 44,
#       "size": 39
#     }
#   },
#   "assignments": {
#     "score": "4.29",
#     "percentiles": {
#       "Greek": 41,
#       "all": 77,
#       "Classics, The": 47,
#       "size": 47
#     }
#   },
#   "materials": {
#     "score": "4.00",
#     "percentiles": {
#       "Greek": 23,
#       "all": 44,
#       "Classics, The": 17,
#       "size": 22
#     }
#   },
#   "recommend": {
#     "score": "3.86",
#     "percentiles": {
#       "Greek": 14,
#       "all": 0,
#       "Classics, The": 10,
#       "size": 15
#     }
#   }
# }
# PHIL 34 Existentialism in Literature and Film id: 37787
# {
#   "workload": {
#     "score": "4.72",
#     "percentiles": {
#       "all": 66,
#       "Philosophy": 35,
#       "size": 35
#     }
#   },
#   "feedback": {
#     "score": "4.28",
#     "percentiles": {
#       "all": 44,
#       "Philosophy": 38,
#       "size": 53
#     }
#   },
#   "section": {
#     "score": "4.17",
#     "percentiles": {
#       "all": 55,
#       "Philosophy": 47,
#       "size": 47
#     }
#   },
#   "overall": {
#     "score": "4.11",
#     "percentiles": {
#       "all": 77,
#       "Philosophy": 36,
#       "size": 48
#     }
#   },
#   "assignments": {
#     "score": "4.22",
#     "percentiles": {
#       "all": 77,
#       "Philosophy": 46,
#       "size": 67
#     }
#   },
#   "materials": {
#     "score": "4.44",
#     "percentiles": {
#       "all": 77,
#       "Philosophy": 49,
#       "size": 74
#     }
#   },
#   "recommend": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 33,
#       "Philosophy": 28,
#       "size": 36
#     }
#   }
# }
# ANTHRO 3000 Reading Course id: 20818
# {
#   "workload": {
#     "score": "14.50",
#     "percentiles": {
#       "Anthropology": 98,
#       "all": 88,
#       "size": 97
#     }
#   },
#   "feedback": {
#     "score": "5.00",
#     "percentiles": {
#       "Anthropology": 92,
#       "all": 88,
#       "size": 76
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "Anthropology": 87,
#       "all": 88,
#       "size": 70
#     }
#   },
#   "overall": {
#     "score": "5.00",
#     "percentiles": {
#       "Anthropology": 96,
#       "all": 88,
#       "size": 82
#     }
#   },
#   "assignments": {
#     "score": "5.00",
#     "percentiles": {
#       "Anthropology": 97,
#       "all": 88,
#       "size": 85
#     }
#   },
#   "materials": {
#     "score": "5.00",
#     "percentiles": {
#       "Anthropology": 96,
#       "all": 88,
#       "size": 82
#     }
#   },
#   "recommend": {
#     "score": "4.50",
#     "percentiles": {
#       "Anthropology": 67,
#       "all": 77,
#       "size": 41
#     }
#   }
# }
# SOCIOL 131 Economy, Society, and Change in East Asia id: 29940
# {
#   "workload": {
#     "score": "5.32",
#     "percentiles": {
#       "all": 77,
#       "Sociology": 52,
#       "size": 45
#     }
#   },
#   "feedback": {
#     "score": "4.27",
#     "percentiles": {
#       "all": 44,
#       "Sociology": 54,
#       "size": 43
#     }
#   },
#   "section": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "Sociology": 63,
#       "size": 52
#     }
#   },
#   "overall": {
#     "score": "3.64",
#     "percentiles": {
#       "all": 0,
#       "Sociology": 17,
#       "size": 12
#     }
#   },
#   "assignments": {
#     "score": "3.45",
#     "percentiles": {
#       "all": 0,
#       "Sociology": 10,
#       "size": 9
#     }
#   },
#   "materials": {
#     "score": "3.73",
#     "percentiles": {
#       "all": 0,
#       "Sociology": 13,
#       "size": 13
#     }
#   },
#   "recommend": {
#     "score": "3.55",
#     "percentiles": {
#       "all": 0,
#       "Sociology": 10,
#       "size": 9
#     }
#   }
# }
# STAT 140 Design of Experiments id: 40251
# {
#   "workload": {
#     "score": "6.45",
#     "percentiles": {
#       "all": 77,
#       "Statistics": 48,
#       "size": 64
#     }
#   },
#   "feedback": {
#     "score": "3.92",
#     "percentiles": {
#       "all": 0,
#       "Statistics": 25,
#       "size": 32
#     }
#   },
#   "section": {
#     "score": "4.39",
#     "percentiles": {
#       "all": 77,
#       "Statistics": 60,
#       "size": 62
#     }
#   },
#   "overall": {
#     "score": "4.26",
#     "percentiles": {
#       "all": 77,
#       "Statistics": 61,
#       "size": 60
#     }
#   },
#   "assignments": {
#     "score": "4.17",
#     "percentiles": {
#       "all": 77,
#       "Statistics": 58,
#       "size": 63
#     }
#   },
#   "materials": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "Statistics": 78,
#       "size": 79
#     }
#   },
#   "recommend": {
#     "score": "4.38",
#     "percentiles": {
#       "all": 77,
#       "Statistics": 69,
#       "size": 65
#     }
#   }
# }
# HISTSCI 99A Tutorial - Senior Year id: 43405
# {
#   "workload": {
#     "score": "12.83",
#     "percentiles": {
#       "all": 88,
#       "History of Science": 98,
#       "size": 97
#     }
#   },
#   "feedback": {
#     "score": "4.62",
#     "percentiles": {
#       "all": 77,
#       "History of Science": 64,
#       "size": 75
#     }
#   },
#   "section": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "History of Science": 61,
#       "size": 70
#     }
#   },
#   "overall": {
#     "score": "4.43",
#     "percentiles": {
#       "all": 77,
#       "History of Science": 63,
#       "size": 73
#     }
#   },
#   "assignments": {
#     "score": "4.62",
#     "percentiles": {
#       "all": 77,
#       "History of Science": 78,
#       "size": 92
#     }
#   },
#   "materials": {
#     "score": "4.29",
#     "percentiles": {
#       "all": 77,
#       "History of Science": 43,
#       "size": 62
#     }
#   },
#   "recommend": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "History of Science": 65,
#       "size": 75
#     }
#   }
# }
# ECON 1776 Religion and the Rise of Capitalism id: 39504
# {
#   "workload": {
#     "score": "5.16",
#     "percentiles": {
#       "size": 50,
#       "all": 77,
#       "European Studies": 38,
#       "Economics": 31,
#       "General Education": 43,
#       "History": 29
#     }
#   },
#   "feedback": {
#     "score": "3.85",
#     "percentiles": {
#       "size": 32,
#       "all": 0,
#       "European Studies": 16,
#       "Economics": 43,
#       "General Education": 35,
#       "History": 20
#     }
#   },
#   "section": {
#     "score": "3.85",
#     "percentiles": {
#       "size": 34,
#       "all": 0,
#       "European Studies": 24,
#       "Economics": 40,
#       "General Education": 42,
#       "History": 18
#     }
#   },
#   "overall": {
#     "score": "3.71",
#     "percentiles": {
#       "size": 29,
#       "all": 22,
#       "European Studies": 7,
#       "Economics": 28,
#       "General Education": 38,
#       "History": 11
#     }
#   },
#   "assignments": {
#     "score": "3.80",
#     "percentiles": {
#       "size": 39,
#       "all": 5,
#       "European Studies": 12,
#       "Economics": 42,
#       "General Education": 49,
#       "History": 18
#     }
#   },
#   "materials": {
#     "score": "3.82",
#     "percentiles": {
#       "size": 32,
#       "all": 11,
#       "European Studies": 8,
#       "Economics": 34,
#       "General Education": 39,
#       "History": 11
#     }
#   },
#   "recommend": {
#     "score": "3.80",
#     "percentiles": {
#       "size": 28,
#       "all": 0,
#       "European Studies": 11,
#       "Economics": 28,
#       "General Education": 38,
#       "History": 13
#     }
#   }
# }
# GHHP 50 The Quality of Health Care in America id: 41228
# {
#   "workload": {
#     "score": "4.17",
#     "percentiles": {
#       "Global Health and Health Policy": 55,
#       "all": 66,
#       "size": 25
#     }
#   },
#   "feedback": {
#     "score": "4.58",
#     "percentiles": {
#       "Global Health and Health Policy": 20,
#       "all": 77,
#       "size": 81
#     }
#   },
#   "section": {
#     "score": "4.56",
#     "percentiles": {
#       "Global Health and Health Policy": 75,
#       "all": 77,
#       "size": 87
#     }
#   },
#   "overall": {
#     "score": "4.64",
#     "percentiles": {
#       "Global Health and Health Policy": 65,
#       "all": 77,
#       "size": 93
#     }
#   },
#   "assignments": {
#     "score": "4.47",
#     "percentiles": {
#       "Global Health and Health Policy": 82,
#       "all": 77,
#       "size": 93
#     }
#   },
#   "materials": {
#     "score": "4.58",
#     "percentiles": {
#       "Global Health and Health Policy": 85,
#       "all": 77,
#       "size": 91
#     }
#   },
#   "recommend": {
#     "score": "4.75",
#     "percentiles": {
# ...
#     }
#   },
#   "feedback": {
#     "score": "3.59",
#     "percentiles": {
#       "all": 0,
#       "Medical Sciences": 26,
#       "Biological and Biomedical Sciences": 16,
#       "size": 21
#     }
#   },
#   "section": {
#     "score": "3.27",
#     "percentiles": {
#       "all": 0,
#       "Medical Sciences": 5,
#       "Biological and Biomedical Sciences": 18,
#       "size": 9
#     }
#   },
#   "overall": {
#     "score": "3.89",
#     "percentiles": {
#       "all": 55,
#       "Medical Sciences": 36,
#       "Biological and Biomedical Sciences": 50,
#       "size": 41
#     }
#   },
#   "assignments": {
#     "score": "3.84",
#     "percentiles": {
#       "all": 33,
#       "Medical Sciences": 47,
#       "Biological and Biomedical Sciences": 50,
#       "size": 43
#     }
#   },
#   "materials": {
#     "score": "3.78",
#     "percentiles": {
#       "all": 11,
#       "Medical Sciences": 37,
#       "Biological and Biomedical Sciences": 43,
#       "size": 28
#     }
#   },
#   "recommend": {
#     "score": "4.11",
#     "percentiles": {
#       "all": 55,
#       "Medical Sciences": 43,
#       "Biological and Biomedical Sciences": 62,
#       "size": 51
#     }
#   }
# }
# PSY 1655R Conceptual Development id: 29700
# {
#   "workload": {
#     "score": "8.21",
#     "percentiles": {
#       "all": 88,
#       "Psychology": 88,
#       "size": 76
#     }
#   },
#   "feedback": {
#     "score": "3.57",
#     "percentiles": {
#       "all": 0,
#       "Psychology": 16,
#       "size": 14
#     }
#   },
#   "section": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 22,
#       "Psychology": 28,
#       "size": 21
#     }
#   },
#   "overall": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 77,
#       "Psychology": 23,
#       "size": 23
#     }
#   },
#   "assignments": {
#     "score": "3.29",
#     "percentiles": {
#       "all": 0,
#       "Psychology": 6,
#       "size": 5
#     }
#   },
#   "materials": {
#     "score": "3.60",
#     "percentiles": {
#       "all": 0,
#       "Psychology": 10,
#       "size": 9
#     }
#   },
#   "recommend": {
#     "score": "4.17",
#     "percentiles": {
#       "all": 55,
#       "Psychology": 28,
#       "size": 28
#     }
#   }
# }
# PHYSICS 151 Mechanics id: 43146
# {
#   "workload": {
#     "score": "7.00",
#     "percentiles": {
#       "all": 88,
#       "Physics": 21,
#       "size": 72
#     }
#   },
#   "feedback": {
#     "score": "4.25",
#     "percentiles": {
#       "all": 44,
#       "Physics": 57,
#       "size": 42
#     }
#   },
#   "section": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "Physics": 73,
#       "size": 52
#     }
#   },
#   "overall": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 77,
#       "Physics": 46,
#       "size": 28
#     }
#   },
#   "assignments": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 61,
#       "Physics": 54,
#       "size": 33
#     }
#   },
#   "materials": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "Physics": 81,
#       "size": 66
#     }
#   },
#   "recommend": {
#     "score": "3.75",
#     "percentiles": {
#       "all": 0,
#       "Physics": 31,
#       "size": 14
#     }
#   }
# }
# CELTIC 137 Celtic Mythology id: 27770
# {
#   "workload": {
#     "score": "3.41",
#     "percentiles": {
#       "all": 22,
#       "Folklore and Mythology": 21,
#       "Medieval Studies": 11,
#       "Celtic": 17,
#       "Celtic Languages and Literatures": 18,
#       "size": 9
#     }
#   },
#   "feedback": {
#     "score": "3.65",
#     "percentiles": {
#       "all": 0,
#       "Folklore and Mythology": 12,
#       "Medieval Studies": 10,
#       "Celtic": 3,
#       "Celtic Languages and Literatures": 4,
#       "size": 22
#     }
#   },
#   "section": {
#     "score": "4.32",
#     "percentiles": {
#       "all": 77,
#       "Folklore and Mythology": 38,
#       "Medieval Studies": 30,
#       "Celtic": 32,
#       "Celtic Languages and Literatures": 18,
#       "size": 57
#     }
#   },
#   "overall": {
#     "score": "3.88",
#     "percentiles": {
#       "all": 55,
#       "Folklore and Mythology": 20,
#       "Medieval Studies": 12,
#       "Celtic": 6,
#       "Celtic Languages and Literatures": 10,
#       "size": 32
#     }
#   },
#   "assignments": {
#     "score": "3.94",
#     "percentiles": {
#       "all": 44,
#       "Folklore and Mythology": 19,
#       "Medieval Studies": 19,
#       "Celtic": 8,
#       "Celtic Languages and Literatures": 15,
#       "size": 43
#     }
#   },
#   "materials": {
#     "score": "4.06",
#     "percentiles": {
#       "all": 55,
#       "Folklore and Mythology": 27,
#       "Medieval Studies": 20,
#       "Celtic": 20,
#       "Celtic Languages and Literatures": 35,
#       "size": 43
#     }
#   },
#   "recommend": {
#     "score": "3.94",
#     "percentiles": {
#       "all": 22,
#       "Folklore and Mythology": 13,
#       "Medieval Studies": 10,
#       "Celtic": 6,
#       "Celtic Languages and Literatures": 5,
#       "size": 32
#     }
#   }
# }
# ANTHRO 2812 Space and Power id: 21882
# {
#   "workload": {
#     "score": "8.06",
#     "percentiles": {
#       "Anthropology": 79,
#       "all": 88,
#       "size": 81
#     }
#   },
#   "feedback": {
#     "score": "4.56",
#     "percentiles": {
#       "Anthropology": 68,
#       "all": 77,
#       "size": 62
#     }
#   },
#   "overall": {
#     "score": "4.00",
#     "percentiles": {
#       "Anthropology": 37,
#       "all": 77,
#       "size": 28
#     }
#   },
#   "assignments": {
#     "score": "4.00",
#     "percentiles": {
#       "Anthropology": 39,
#       "all": 61,
#       "size": 33
#     }
#   },
#   "materials": {
#     "score": "4.00",
#     "percentiles": {
#       "Anthropology": 29,
#       "all": 44,
#       "size": 26
#     }
#   },
#   "recommend": {
#     "score": "4.22",
#     "percentiles": {
#       "Anthropology": 47,
#       "all": 66,
#       "size": 38
#     }
#   }
# }
# EXPOS 20 Expository Writing 20 id: 45929
# {
#   "workload": {
#     "score": "5.58",
#     "percentiles": {
#       "all": 77,
#       "Expository Writing": 54,
#       "size": 52
#     }
#   },
#   "feedback": {
#     "score": "4.33",
#     "percentiles": {
#       "all": 55,
#       "Expository Writing": 35,
#       "size": 73
#     }
#   },
#   "section": {
#     "score": "4.21",
#     "percentiles": {
#       "all": 66,
#       "Expository Writing": 51,
#       "size": 91
#     }
#   },
#   "overall": {
#     "score": "3.97",
#     "percentiles": {
#       "all": 66,
#       "Expository Writing": 42,
#       "size": 69
#     }
#   },
#   "assignments": {
#     "score": "3.96",
#     "percentiles": {
#       "all": 44,
#       "Expository Writing": 47,
#       "size": 78
#     }
#   },
#   "materials": {
#     "score": "4.11",
#     "percentiles": {
#       "all": 55,
#       "Expository Writing": 45,
#       "size": 73
#     }
#   },
#   "recommend": {
#     "score": "4.00",
#     "percentiles": {
#       "all": 33,
#       "Expository Writing": 39,
#       "size": 60
#     }
#   }
# }
# JAPNHIST 270 Early Modern Japanese History id: 40017
# {
#   "workload": {
#     "score": "6.50",
#     "percentiles": {
#       "East Asian Languages and Civilizations": 46,
#       "all": 77,
#       "History": 55,
#       "Japanese History": 39,
#       "size": 57
#     }
#   },
#   "feedback": {
#     "score": "5.00",
#     "percentiles": {
#       "East Asian Languages and Civilizations": 89,
#       "all": 88,
#       "History": 90,
#       "Japanese History": 87,
#       "size": 87
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "East Asian Languages and Civilizations": 86,
#       "all": 88,
#       "History": 85,
#       "Japanese History": 69,
#       "size": 78
#     }
#   },
#   "overall": {
#     "score": "4.80",
#     "percentiles": {
#       "East Asian Languages and Civilizations": 78,
#       "all": 88,
#       "History": 84,
#       "Japanese History": 76,
#       "size": 80
#     }
#   },
#   "assignments": {
#     "score": "5.00",
#     "percentiles": {
#       "East Asian Languages and Civilizations": 94,
#       "all": 88,
#       "History": 95,
#       "Japanese History": 89,
#       "size": 95
#     }
#   },
#   "materials": {
#     "score": "5.00",
#     "percentiles": {
#       "East Asian Languages and Civilizations": 93,
#       "all": 88,
#       "History": 94,
#       "Japanese History": 91,
#       "size": 94
#     }
#   },
#   "recommend": {
#     "score": "4.75",
#     "percentiles": {
#       "East Asian Languages and Civilizations": 76,
#       "all": 77,
#       "History": 80,
#       "Japanese History": 70,
#       "size": 75
#     }
#   }
# }
# ASTRON 98 Research Tutorial in Astrophysics id: 46975
# {
#   "workload": {
#     "score": "0.00"
#   },
#   "feedback": {
#     "score": "0.00"
#   },
#   "section": {
#     "score": "0.00"
#   },
#   "overall": {
#     "score": "0.00"
#   },
#   "assignments": {
#     "score": "0.00"
#   },
#   "materials": {
#     "score": "0.00"
#   },
#   "recommend": {
#     "score": "0.00"
#   }
# }
# PHYSICS 16 Mechanics and Special Relativity id: 43144
# {
#   "workload": {
#     "score": "12.33",
#     "percentiles": {
#       "all": 88,
#       "General Education": 96,
#       "Physics": 87,
#       "size": 97
#     }
#   },
#   "feedback": {
#     "score": "3.13",
#     "percentiles": {
#       "all": 0,
#       "General Education": 8,
#       "Physics": 12,
#       "size": 9
#     }
#   },
#   "section": {
#     "score": "4.67",
#     "percentiles": {
#       "all": 77,
#       "General Education": 96,
#       "Physics": 83,
#       "size": 81
#     }
#   },
#   "overall": {
#     "score": "3.92",
#     "percentiles": {
#       "all": 55,
#       "General Education": 55,
#       "Physics": 41,
#       "size": 34
#     }
#   },
#   "assignments": {
#     "score": "4.04",
#     "percentiles": {
#       "all": 66,
#       "General Education": 70,
#       "Physics": 59,
#       "size": 52
#     }
#   },
#   "materials": {
#     "score": "4.13",
#     "percentiles": {
#       "all": 66,
#       "General Education": 68,
#       "Physics": 56,
#       "size": 49
#     }
#   },
#   "recommend": {
#     "score": "4.12",
#     "percentiles": {
#       "all": 55,
#       "General Education": 64,
#       "Physics": 52,
#       "size": 44
#     }
#   }
# }
# FRSEMR 40L Free Speech id: 43095
# {
#   "workload": {
#     "score": "5.00",
#     "percentiles": {
#       "Freshman Seminar": 91,
#       "all": 77,
#       "Freshman Seminars": 93,
#       "size": 40
#     }
#   },
#   "feedback": {
#     "score": "4.67",
#     "percentiles": {
#       "Freshman Seminar": 77,
#       "all": 88,
#       "Freshman Seminars": 71,
#       "size": 69
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "Freshman Seminar": 83,
#       "all": 88,
#       "Freshman Seminars": 81,
#       "size": 87
#     }
#   },
#   "overall": {
#     "score": "4.42",
#     "percentiles": {
#       "Freshman Seminar": 52,
#       "all": 77,
#       "Freshman Seminars": 40,
#       "size": 57
#     }
#   },
#   "assignments": {
#     "score": "4.17",
#     "percentiles": {
#       "Freshman Seminar": 44,
#       "all": 77,
#       "Freshman Seminars": 31,
#       "size": 46
#     }
#   },
#   "materials": {
#     "score": "4.25",
#     "percentiles": {
#       "Freshman Seminar": 46,
#       "all": 77,
#       "Freshman Seminars": 40,
#       "size": 44
#     }
#   },
#   "recommend": {
#     "score": "4.25",
#     "percentiles": {
#       "Freshman Seminar": 38,
#       "all": 66,
#       "Freshman Seminars": 33,
#       "size": 40
#     }
#   }
# }
# HIST 1155 Early Modern Europe, 1450-1789 id: 41477
# {
#   "workload": {
#     "score": "4.03",
#     "percentiles": {
#       "all": 66,
#       "History": 8,
#       "European Studies": 11,
#       "size": 19
#     }
#   },
#   "feedback": {
#     "score": "3.45",
#     "percentiles": {
#       "all": 0,
#       "History": 10,
#       "European Studies": 4,
#       "size": 15
#     }
#   },
#   "section": {
#     "score": "3.68",
#     "percentiles": {
#       "all": 0,
#       "History": 14,
#       "European Studies": 16,
#       "size": 22
#     }
#   },
#   "overall": {
#     "score": "4.23",
#     "percentiles": {
#       "all": 77,
#       "History": 38,
#       "European Studies": 35,
#       "size": 57
#     }
#   },
#   "assignments": {
#     "score": "4.09",
#     "percentiles": {
#       "all": 66,
#       "History": 38,
#       "European Studies": 32,
#       "size": 56
#     }
#   },
#   "materials": {
#     "score": "4.41",
#     "percentiles": {
#       "all": 77,
#       "History": 51,
#       "European Studies": 49,
#       "size": 72
#     }
#   },
#   "recommend": {
#     "score": "4.27",
#     "percentiles": {
#       "all": 77,
#       "History": 40,
#       "European Studies": 44,
#       "size": 57
#     }
#   }
# }
# PSY 2358R Memory id: 43116
# {
#   "workload": {
#     "score": "10.50",
#     "percentiles": {
#       "all": 88,
#       "Psychology": 96,
#       "size": 91
#     }
#   },
#   "feedback": {
#     "score": "4.67",
#     "percentiles": {
#       "all": 88,
#       "Psychology": 64,
#       "size": 60
#     }
#   },
#   "overall": {
#     "score": "4.50",
#     "percentiles": {
#       "all": 77,
#       "Psychology": 54,
#       "size": 54
#     }
#   },
#   "assignments": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Psychology": 93,
#       "size": 95
#     }
#   },
#   "materials": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "Psychology": 92,
#       "size": 94
#     }
#   },
#   "recommend": {
#     "score": "4.67",
#     "percentiles": {
#       "all": 77,
#       "Psychology": 66,
#       "size": 67
#     }
#   }
# }
# SOC-STD 98EO Culture and Society id: 43324
# {
#   "workload": {
#     "score": "5.30",
#     "percentiles": {
#       "Social Studies": 15,
#       "all": 77,
#       "size": 39
#     }
#   },
#   "feedback": {
#     "score": "4.80",
#     "percentiles": {
#       "Social Studies": 74,
#       "all": 88,
#       "size": 69
#     }
#   },
#   "section": {
#     "score": "5.00",
#     "percentiles": {
#       "Social Studies": 83,
#       "all": 88,
#       "size": 78
#     }
#   },
#   "overall": {
#     "score": "4.40",
#     "percentiles": {
#       "Social Studies": 41,
#       "all": 77,
#       "size": 46
#     }
#   },
#   "assignments": {
#     "score": "4.60",
#     "percentiles": {
#       "Social Studies": 72,
#       "all": 77,
#       "size": 72
#     }
#   },
#   "materials": {
#     "score": "4.60",
#     "percentiles": {
#       "Social Studies": 61,
#       "all": 77,
#       "size": 65
#     }
#   },
#   "recommend": {
#     "score": "4.60",
#     "percentiles": {
#       "Social Studies": 59,
#       "all": 77,
#       "size": 61
#     }
#   }
# }
# ENGLISH CHCR Advanced Poetry id: 41028
# {
#   "workload": {
#     "score": "3.38",
#     "percentiles": {
#       "all": 22,
#       "English": 2,
#       "size": 14
#     }
#   },
#   "feedback": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "English": 90,
#       "size": 93
#     }
#   },
#   "overall": {
#     "score": "4.89",
#     "percentiles": {
#       "all": 88,
#       "English": 84,
#       "size": 93
#     }
#   },
#   "assignments": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "English": 95,
#       "size": 98
#     }
#   },
#   "materials": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "English": 94,
#       "size": 98
#     }
#   },
#   "recommend": {
#     "score": "5.00",
#     "percentiles": {
#       "all": 88,
#       "English": 92,
#       "size": 97
#     }
#   }
# }
# SOC-STD 98MI Migration in Theory and Practice id: 40207
# {
#   "workload": {
#     "score": "4.61",
#     "percentiles": {
#       "Social Studies": 8,
#       "Ethnicity, Migration, Rights": 54,
#       "all": 66,
#       "size": 28
#     }
#   },
#   "feedback": {
#     "score": "4.67",
#     "percentiles": {
#       "Social Studies": 62,
#       "Ethnicity, Migration, Rights": 78,
#       "all": 88,
#       "size": 60
#     }
#   },
#   "section": {
#     "score": "4.50",
#     "percentiles": {
#       "Social Studies": 37,
#       "Ethnicity, Migration, Rights": 65,
#       "all": 77,
#       "size": 41
#     }
#   },
#   "overall": {
#     "score": "4.44",
#     "percentiles": {
#       "Social Studies": 46,
#       "Ethnicity, Migration, Rights": 65,
#       "all": 77,
#       "size": 50
#     }
#   },
#   "assignments": {
#     "score": "4.22",
#     "percentiles": {
#       "Social Studies": 40,
#       "Ethnicity, Migration, Rights": 59,
#       "all": 77,
#       "size": 43
#     }
#   },
#   "materials": {
#     "score": "4.22",
#     "percentiles": {
#       "Social Studies": 25,
#       "Ethnicity, Migration, Rights": 53,
#       "all": 77,
#       "size": 35
#     }
#   },
#   "recommend": {
#     "score": "4.56",
#     "percentiles": {
#       "Social Studies": 55,
#       "Ethnicity, Migration, Rights": 68,
#       "all": 77,
#       "size": 56
#     }
#   }
# }
