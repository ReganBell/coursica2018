# %% [markdown]
# # my.harvard Mappers
# Below are all of the mappings from the raw my.harvard scrape to the parsed offerings objects in the database. Each one is broken into its own cell to make testing easier. For testing, `genSamples`, `genSample`, and `Mapper`'s `uniques` method come in handy.

# %%
from jupyterImport import enableJupyterImports
enableJupyterImports()
from Utilities import find, Mapper, MultiReplace, genSamples, genSample, name
from load_raw_data import myHarvard
import sys, json
# Out:
# importing Jupyter notebook from Utilities.ipynb
# importing Jupyter notebook from load_raw_data.ipynb

# %%
deptReplace = MultiReplace({
  '&': 'and', 
  'Biol$': 'Biology', 
  ' Sci ': ' Science ', 
  ' Chem ': ' Chemistry ',
  ' Amer ': ' American ',
  '^Biolog ': 'Biological ',
  ' Bio ': ' Biology ',
  'Med$': 'Medicine',
  'Pharm$': 'Pharmacology',
  'GenEd: ': '',
  'Hlth$': 'Health',
  'Aesthetic and Interpretive': 'Aesthetic and Interpretive Understanding',
  'Pol$': 'Policy',
  ' Regen ': ' Regenerative ',
  'Science of Physical Universe': 'Science of the Physical Universe',
  '^E Asian': 'East Asian',
  'Math Reasoning': 'Mathematical Reasoning',
  'E Europe and Cntrl Asia': 'Eastern Europe, and Central Asia',
  'E Europe, Central Asia': 'Eastern Europe, and Central Asia',
  'Biomedical Sci': 'Biomedical Sciences',
  '^Adv Stud': 'Advanced Studies',
  'and Civ': 'and Civilizations',
  ' Langs ': ' Languages ',
  'Lit$': 'Literature',
  'Arch, Landscape and Urban Plan': 'Architecture, Landscape, and Urban Planning',
  'Envi Science': 'Environmental Science'
})

# %%
def mapDepartments(inputs):
  depts, primary = inputs
  depts = depts if isinstance(depts, list) else [depts]
  depts = [deptReplace.sub(dept) for dept in depts if dept != primary]
  return {'departments': depts, 'primaryDepartment': deptReplace.sub(primary)}
departmentsMapper = Mapper(['IS_SCL_DESCR_IS_SCL_DESCRM', 'IS_SCL_DESCR_IS_SCL_DESCRD'], mapDepartments)

# %%
prepReplace = MultiReplace({
  'Prerequisite: ': '',
  '^\*': '',
  '\.$': ''
})
def mapRecommendedPrep(prep):
  return {'recommendedPrep': prepReplace.sub(prep)} if prep else {}
recommendedPrepMapper = Mapper('RecPrepDescr', mapRecommendedPrep)

# %%
consentRequiredMapper = Mapper('IS_SCL_DESCRSHORT_HU_CONSENT', Mapper.noChange('consentRequired'))

# %%
formatMap = {
  'Read Rsch': 'Reading and Research',
  'Doc Diss': 'Doctoral Dissertation',
  'ReadingCrs': 'Reading Course',
  'Fresh Sem': 'Freshman Seminar',
  'JrTutorial': 'Junior Tutorial',
  'SrTutorial': 'Senior Tutorial',
  'Rsrch Wksh': 'Research Workshop',
  'Rsrch Sem': 'Research Seminar',
  'Soph Tutor': 'Sophomore Tutorial',
  'Lab Rsrch': 'Lab Research',
  'Sem Wrkshp': 'Seminar Workshop',
  'House Sem': 'House Seminar'
}
def mapFormat(frmt):
  return {'format': formatMap[frmt] if frmt in formatMap else frmt} if frmt else {}
formatMapper = Mapper('SSR_COMPONENT_NAME', mapFormat)

# %%
notesMapper = Mapper('HU_COURSE_PREQ', Mapper.noChange('notes'))

# %%
gradingBasisMapper = Mapper('IS_SCL_DESCR100_HU_SCL_GRADE_BASIS', Mapper.noChange('gradingBasis'))

# %%
unitsMapper = Mapper('UnitsDisplay', Mapper.noChange('units'))

# %%
classNumberMapper = Mapper('CLASS_NBR', Mapper.noChange('classNumber'))

# %%
courseIdMapper = Mapper('CRSE_ID', Mapper.noChange('courseId'))

# %%
enrollmentCapMapper = Mapper('ENRL_CAP', Mapper.noChange('enrollmentCap'))

# %%
groupMapper = Mapper('Subject', Mapper.noChange('group'))

# %%
titleReplace = MultiReplace({'Expository Writing 20: ': '' })
def mapTitle(inputs):
  (title, expos) = inputs
  fullTitle = title + ': ' + expos if expos else title
  return {'title': titleReplace.sub(fullTitle)}
titleMapper = Mapper(['Title', 'DESCRFORMAL_COURSE_TOPIC'], mapTitle)

# %%
def mapGenEds(genEds):
  return {'genEds': genEds if isinstance(genEds, list) else [genEds]} if genEds else {}
genEdsMapper = Mapper('IS_SCL_DESCR100_HU_SCL_ATTR_GE', mapGenEds)

# %%
levelMapper = Mapper('IS_SCL_DESCR100_HU_SCL_ATTR_LEVL', Mapper.noChange('level'))

# %%
courseSiteMapper = Mapper('URL_URLNAME', Mapper.noChange('courseSite'))

# %%
def mapCrossReg(crossReg):
  return {'crossReg': crossReg if isinstance(crossReg, list) else [crossReg]} if crossReg else {}
crossRegMapper = Mapper('IS_SCL_DESCR100_HU_SCL_ATTR_XREG', mapCrossReg)

# %%
def mapTermYear(inputs):
  (normal, likely) = inputs
  if not likely:
    return {'term': normal.split(' ')[1], 'year': normal.split(' ')[0]}
  else:
    return {'likelyTerm': likely.split(' ')[1], 'likelyYear': likely.split(' ')[0]}
termYearMapper = Mapper(['IS_SCL_DESCR_IS_SCL_DESCRH', 'IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED'], mapTermYear)

# %%
descReplace = MultiReplace({'<p>': '', '</p>': ''})
def mapDescription(desc):
  return {'description': descReplace.sub(desc)} if desc else {}
descriptionMapper = Mapper('IS_SCL_DESCR', mapDescription)

# %%
import re
def mapNumber(inputs):
  (number, group) = inputs
  matched = re.compile('\d\d*').findall(number)
  return {
  'number': number,
  'numberInt': int(matched[0]) if len(matched) > 0 else -1,
  'numberAlt': group + number
}
numberMapper = Mapper(['CATALOG_NBR', 'Subject'], mapNumber)

# %%
def mapProfs(profs):
  if not profs:
    return {}
  if not isinstance(profs, list):
    print 'not list -------'
    print json.dumps(profs, indent=2)
  def mapProf(prof):
    fullName = prof['Name']
    return {'displayName': name(fullName), 'matchName': name(fullName, match=True)}
  return {'profs': [mapProf(p) for p in profs]}
profsMapper = Mapper('DESCRLONG_DETAILS', mapProfs)

# %%
def mapObjectID(inputs):
  (classNumber, courseId) = inputs
  classNumber = '0' if not classNumber else classNumber
  return {'objectID': '_'.join([courseId, classNumber])}
objectIDMapper = Mapper(['CLASS_NBR', 'CRSE_ID'], mapObjectID)

# %%
def mapTime(time):
  if time is None:
    return None
  hour = int(time.split(':')[0])
  minutes = int(time.split(':')[1].replace('am', '').replace('pm', '')) if ':' in time else None
  if minutes and minutes == 59:
    return '1' if hour == 12 else unicode(hour + 1)
  elif minutes and minutes == 29:
    return unicode(hour) + ':' + '30'
  elif minutes:
    return unicode(hour) + ':' + unicode(minutes)
  else:
    return unicode(hour)
    
daysReplace = MultiReplace({'Mo': 'M', 'We': 'W', 'Fr': 'F'})
def mapDays(days):
    return daysReplace.sub(days).split(' ')

def assignIf(dictionary):
  def assign(key, value):
    if value:
      dictionary[key] = value
  return assign

locReplace = MultiReplace({
  ' \(FAS\)': '',
  ' \(SEAS\)': '',
  ' \(HLS\)': '',
  'Bldg': 'Building', 
  'Ctr': 'Center',
  ' \(HDS\)': '',
  ' \(GSD\)': ''
})
def mapLocName(name):
  return locReplace.sub(name) if name else None

def mapLatLong(latLong):
  return latLong if latLong != '0' else None

def mapSession(inputs):
  (start, end, days, locName, locNumber, latitude, longitude) = inputs
  session = {}; seshSet = assignIf(session)
  seshSet('start', mapTime(start))
  seshSet('end', mapTime(end))
  seshSet('days', mapDays(days)) 
  location = {}; locSet = assignIf(location)
  locSet('name', mapLocName(locName))
  locSet('number', locNumber)
  locSet('longitude', mapLatLong(longitude))
  locSet('latitude', mapLatLong(latitude))
  if len(location.keys()) > 1:
    session['location'] = location
  return session

sessionKeys = [
  'IS_SCL_TIME_START', 
  'IS_SCL_TIME_END', 
  'IS_SCL_MEETING_PAT', 
  'IS_SCL_DESCR_IS_SCL_DESCRG',
  'BLDG_CD',
  'HU_LATITUDE',
  'HU_LONGITUDE'
]
def mapSessions(inputs):
  (multiSection, start, end, days, locNameOrNames, locNumber, latitude, longitude) = inputs
  if days == 'TBA':
    return {}
  if multiSection:
    sessions = []
    locNameOrNames = locNameOrNames if locNameOrNames else [None] * len(multiSection)
    locNames = locNameOrNames if isinstance(locNameOrNames, list) else [locNameOrNames] * len(multiSection)
    for session, locName in zip(multiSection, locNames):
      mapped = {}
      session['IS_SCL_DESCR_IS_SCL_DESCRG'] = locName
      Mapper(sessionKeys, mapSession).map(session, mapped)
      sessions.append(mapped)
    return {'sessions': sessions}
  elif days is not None:
    return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
  else:
    return {}
    
sessionsMapper = Mapper(['MultiSection'] + sessionKeys, mapSessions)

# %%
examDateTimeMapper = Mapper('IS_SCL_DESCR_HU_SCL_EXAM_GROUP', Mapper.noChange('examDateTime'))

# %%
enrollmentStatusMapper = Mapper('EnrlDisplay', Mapper.noChange('enrollmentStatus'))

# %%
mappers = [
  departmentsMapper,
  recommendedPrepMapper,
  consentRequiredMapper,
  formatMapper,
  notesMapper,
  gradingBasisMapper,
  unitsMapper,
  classNumberMapper,
  courseIdMapper,
  enrollmentCapMapper,
  groupMapper,
  titleMapper,
  genEdsMapper,
  levelMapper,
  courseSiteMapper,
  crossRegMapper,
  termYearMapper,
  descriptionMapper,
  numberMapper,
  profsMapper,
  objectIDMapper,
  sessionsMapper,
  examDateTimeMapper,
  enrollmentStatusMapper
]

# %%
rawOfferings = myHarvard()

# %%
offerings = []
for raw in rawOfferings:
  parsed = {}
  for mapper in mappers:
    mapper.map(raw, to=parsed)
  offerings.append(parsed)
# Out:
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x1072937e8>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Psychology",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-113704/",
#   "Title": "Diagnostic Interviewing",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "Psychology",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "N",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "Psychology",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "Instructor",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=PSY&catnbr=2460&classsection=&classnbr=&crseid=113704&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>Students develop clinical interviewing and diagnostic skills using the Structured Clinical Interview for DSM-III-R and other instruments. Examines issues in diagnosis and assessment; provides exposure to psychopathology syndromes via tapes and clinical interviews.</p>",
#   "SSR_COMPONENT_NAME": "Seminar",
#   "Description": "?p?Students develop clinical interviewing and diagnostic skills using the Structured Clinical Interview for DSM-III-R and other instruments. Examines issues in diagnosis and assessment; provides",
#   "EFFDT": "2017-08-15-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": "PSYC",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=PSY&catnbr=2460&classsection=&classnbr=&crseid=113704&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "PSY24600012192",
#   "Removed": false,
#   "HU_COURSE_PREQ": "Graduate students only.",
#   "Name": "Diagnostic Interviewing",
#   "ACAD_ORG_PRIMARY_ORG": "PSYC",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "Instructor Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>Students develop clinical interviewing and diagnostic skills using the Structured Clinical Interview for DSM-III-R and other instruments. Examines issues in diagnosis and assessment; provides exposure to psychopathology syndromes via tapes and clinical interviews.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"PSYC\" num=\" 2460\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "SOCSCI",
#   "SearchKey": "dlKX8ebBzvu8M5oPiHujImwonr4=",
#   "CATALOG_NBR": "2460",
#   "CRSE_ID": "113704",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "Primarily for Graduate Students",
#   "IS_SCL_DESCR100": "Diagnostic Interviewing",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Seminar",
#   "Subject": "PSY"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x107293998>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Democracy, Politics & Insts",
#   "LAST_NAME": "Temkin",
#   "Title": "The United States and the World: Politics, Policy, and the Uses of History",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "HKS Government",
#   "IS_SCL_DESCR_IS_SCL_DESCRL": "Moshik Temkin",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "N",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Harvard Kennedy School",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "HKS Government",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=DPI&catnbr=%20714&classsection=&classnbr=&crseid=170226&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>This course provides a historical framework for understanding the influence of the United States on the wider world and the impact of global events and trends and policymaking in the United States. It also focuses on the ways in which policymakers, activists, and citizens can, do, and should (or should not) make use of history in their professional and public lives. Our first goal is to examine the diverse connections between American and international policy history. Our second goal is to permi</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?This course provides a historical framework for understanding the influence of the United States on the wider world and the impact of global events and trends and policymaking in the United States.",
#   "EFFDT": "2017-08-30-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Harvard Kennedy School",
#   "ACAD_ORG": "GOV",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=DPI&catnbr=%20714&classsection=&classnbr=&crseid=170226&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "DPI 7140012192",
#   "Removed": false,
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/hks-170226/",
#   "DESCRLONG_DETAILS": [
#     {
#       "Name": "Moshik Temkin",
#       "URL": "http://www.hks.harvard.edu/about/faculty-staff-directory/Moshik-Temkin/(page)/faculty",
#       "Photo": "",
#       "EMPLID": "qzQubCGaHxALjqTTuTGSmA==",
#       "Key": "Moshik Temkin",
#       "Email": ""
#     }
#   ],
#   "Name": "The United States and the World: Politics, Policy, and the Uses of History",
#   "ACAD_ORG_PRIMARY_ORG": "GOV",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "HKS Letter Graded",
#   "ACAD_CAREER": "HKS",
#   "IS_SCL_DESCR": "<p>This course provides a historical framework for understanding the influence of the United States on the wider world and the impact of global events and trends and policymaking in the United States. It also focuses on the ways in which policymakers, activists, and citizens can, do, and should (or should not) make use of history in their professional and public lives. Our first goal is to examine the diverse connections between American and international policy history. Our second goal is to permit you to become more self-aware, reflective, and skilled at using and thinking about history in variety of public and policy settings. Adopting a loosely chronological structure, and making use of sources both written and visual, we will grapple with issues that have provoked much debate among historians and policymakers: What are the sources, dynamics, and long-term implications of the American rise to global power? How have American mass production and culture conquered the global market? More broadly, what have been the roles of the United States in the wider world? What place has the wider world had in shaping American domestic policies? What responsibility (for better or for worse) does the United States bear for the way the world looks today? And how can this history help us in understanding, and formulating, public policy in the future?&rdquo;</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"HKS\" num=\"DPI 714LL\" sect=\"01\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "HKS",
#   "SearchKey": "T1iSrBjwe5gYKV_2LPpO8n2pvWQ=",
#   "CATALOG_NBR": "714",
#   "CRSE_ID": "170226",
#   "UnitsDisplay": "4",
#   "IS_SCL_DESCR100": "The United States and the World: Politics, Policy, and the Uses of History",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "ShopCartOpenCheck": "N",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_AA": "Democracy, Politics, and Institutions",
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "DPI"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x107293830>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Earth & Planetary Sciences",
#   "LAST_NAME": "Ishii",
#   "Title": "Consequences of Earthquakes",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "Earth & Planetary Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRL": "Miaki Ishii",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "Y",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "Mathematics 21a, b or Applied Mathematics 21a, b (may be taken concurrently); or equivalent.",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "Earth & Planetary Sciences",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=E-PSCI&catnbr=%20166&classsection=&classnbr=&crseid=110819&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>Introduction to seismology with a focus on conceptual understanding of seismic phenomena. Emphasis will be on earthquakes, e.g., detection, mechanism, characteristics, statistics, hazard, and relationship to dynamics. Broader topics such as the types of seismological data and inferences of the Earth's internal structure also will be covered.</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?Introduction to seismology with a focus on conceptual understanding of seismic phenomena. Emphasis will be on earthquakes, e.g., detection, mechanism, characteristics, statistics, hazard, and",
#   "EFFDT": "2017-08-15-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": "E&PS",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=E-PSCI&catnbr=%20166&classsection=&classnbr=&crseid=110819&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "E-PSCI 1660012192",
#   "Removed": false,
#   "HU_COURSE_PREQ": "Course includes a weekly three-hour lab to be arranged. This course fulfills the EPS sub-discipline requirement of Geology, Geophysics and Planetary Science. Given in alternate years.",
#   "DESCRLONG_DETAILS": [
#     {
#       "Name": "Miaki Ishii",
#       "URL": "",
#       "Photo": "",
#       "EMPLID": "32IyIJwfSofTfFRTDaKLAg==",
#       "Key": "Miaki Ishii",
#       "Email": ""
#     }
#   ],
#   "Name": "Consequences of Earthquakes",
#   "ACAD_ORG_PRIMARY_ORG": "E&PS",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-22-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>Introduction to seismology with a focus on conceptual understanding of seismic phenomena. Emphasis will be on earthquakes, e.g., detection, mechanism, characteristics, statistics, hazard, and relationship to dynamics. Broader topics such as the types of seismological data and inferences of the Earth's internal structure also will be covered.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"EAPS\" num=\" 166\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "SCIENCE",
#   "SearchKey": "UzNjsAirI4KC2Tw0WPwdFVWM07Q=",
#   "CATALOG_NBR": "166",
#   "CRSE_ID": "110819",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-110819/",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "Consequences of Earthquakes",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "E-PSCI"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x107293908>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Uyghur",
#   "LAST_NAME": "Elliott",
#   "Title": "Intermediate/Advanced Uyghur",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": [
#     "Russia, E Europe, Central Asia",
#     "East Asian Langs & Civ"
#   ],
#   "IS_SCL_DESCR_IS_SCL_DESCRL": "Mark Elliott",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "Y",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "Uyghur 120A or permission of instructor.",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "East Asian Langs & Civ",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=UYGHUR&catnbr=%20120B&classsection=&classnbr=&crseid=124526&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>Continuation of Uyghur 120A.</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?Continuation of Uyghur 120A.?/p?",
#   "EFFDT": "2017-08-15-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": [
#     "REECA",
#     "EALC"
#   ],
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=UYGHUR&catnbr=%20120B&classsection=&classnbr=&crseid=124526&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "UYGHUR 120B0012192",
#   "Removed": false,
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-124526/",
#   "DESCRLONG_DETAILS": [
#     {
#       "Name": "Mark Elliott",
#       "URL": "",
#       "Photo": "",
#       "EMPLID": "rb8zCDUancrns2Ez4V8HKQ==",
#       "Key": "Mark Elliott",
#       "Email": ""
#     }
#   ],
#   "Name": "Intermediate/Advanced Uyghur",
#   "ACAD_ORG_PRIMARY_ORG": "EALC",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>Continuation of Uyghur 120A.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"EALC\" num=\"UYGH 120B\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "ARTS-HUM",
#   "SearchKey": "vuEMVTrj4aUecEd3GkbV3nT/Wzs=",
#   "CATALOG_NBR": "120B",
#   "CRSE_ID": "124526",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "Intermediate/Advanced Uyghur",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "UYGHUR"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x107387170>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Economics",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-111378/",
#   "Title": "International Monetary Economics",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "Economics",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "Y",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "Economics 1010b or 1011b.",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "Economics",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=ECON&catnbr=1530&classsection=&classnbr=&crseid=111378&strm=2188?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>This is an intermediate level international finance and macroeconomics course that uses a mix of theoretical, empirical and policy frameworks to analyze topical problems in international finance. The topics include exchange rate determination, currency interventions, monetary policy coordination, capital flows and currency crises.</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?This is an intermediate level international finance and macroeconomics course that uses a mix of theoretical, empirical and policy frameworks to analyze topical problems in international finance.",
#   "EFFDT": "2017-07-13-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2018 Fall",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": "ECON",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=ECON&catnbr=1530&classsection=&classnbr=&crseid=111378&strm=2188?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "ECON15300012188",
#   "Removed": false,
#   "HU_COURSE_PREQ": "Writing requirement: A research paper is required. This course meets the concentration writing requirement. May not be taken for credit with Economics 1531.",
#   "Name": "International Monetary Economics",
#   "ACAD_ORG_PRIMARY_ORG": "ECON",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>This is an intermediate level international finance and macroeconomics course that uses a mix of theoretical, empirical and policy frameworks to analyze topical problems in international finance. The topics include exchange rate determination, currency interventions, monetary policy coordination, capital flows and currency crises.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"ECON\" num=\" 1530\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "SOCSCI",
#   "SearchKey": "Tm4dCNhpSfb628c7AuLcLHlB6b0=",
#   "CATALOG_NBR": "1530",
#   "CRSE_ID": "111378",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "International Monetary Economics",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "ECON"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x107412950>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "GenEd: Ethical Reasoning",
#   "LAST_NAME": "Jones",
#   "Title": "Medical Ethics and History",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": [
#     "History of Science",
#     "General Education"
#   ],
#   "IS_SCL_DESCR_IS_SCL_DESCRL": "David Shumway Jones",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "N",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "General Education",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LDD": "None",
#   "LinkURL": "http://ses.my.harvard.edu:80subject=ETHRSON&catnbr=%20%2033&classsection=&classnbr=&crseid=108405&strm=2188?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>Disease and medicine have generated ethical dilemmas that have challenged patients and doctors for centuries, from abortion and euthanasia to informed consent and compulsory treatment. Although moral philosophy can clarify the relevant issues, resolution often depends on the details of the specific clinical and social contexts. Taking a historical approach to medical ethics, this class explores how the moral discourse in health care has changed over time in order to understand how social factors</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?Disease and medicine have generated ethical dilemmas that have challenged patients and doctors for centuries, from abortion and euthanasia to informed consent and compulsory treatment. Although",
#   "EFFDT": "2017-08-01-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2018 Fall",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": [
#     "HSCI",
#     "GENED"
#   ],
#   "CombinedSectionClass": "hide",
#   "ACAD_ORG_PRIMARY_ORG": "GENED",
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=ETHRSON&catnbr=%20%2033&classsection=&classnbr=&crseid=108405&strm=2188?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "ETHRSON 330012188",
#   "Removed": false,
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-108405/",
#   "DESCRLONG_DETAILS": [
#     {
#       "Name": "David Shumway Jones",
#       "URL": "",
#       "Photo": "",
#       "EMPLID": "BnVoFbtpWiJm4ylq83uYVw==",
#       "Key": "David Shumway Jones",
#       "Email": ""
#     }
#   ],
#   "Name": "Medical Ethics and History",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_GE": "Ethical Reasoning",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>Disease and medicine have generated ethical dilemmas that have challenged patients and doctors for centuries, from abortion and euthanasia to informed consent and compulsory treatment. Although moral philosophy can clarify the relevant issues, resolution often depends on the details of the specific clinical and social contexts. Taking a historical approach to medical ethics, this class explores how the moral discourse in health care has changed over time in order to understand how social factors influence the persuasiveness of moral arguments. The focus will be on medical practice in the United States in the twentieth century.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"GNED\" num=\"ETHREA 33\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "FAS",
#   "SearchKey": "el44yG3Gnh_ma7jt_db9_PZ4M7k=",
#   "CATALOG_NBR": "33",
#   "CRSE_ID": "108405",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "Primarily for Undergraduate Students",
#   "IS_SCL_DESCR100": "Medical Ethics and History",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "ClassStartDt": null,
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "ETHRSON"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x1073ecb00>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Sociology",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-112354/",
#   "Title": "Proseminar on Inequality and Social Policy II",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": [
#     "African & African Amer Studies",
#     "Sociology"
#   ],
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "Y",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "SUP-921",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "Sociology",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "Instructor",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=SOCIOL&catnbr=%20296B&classsection=&classnbr=&crseid=112354&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>Deals with causes and possible cures for economic inequality, including skill differences, discrimination, immigration, household composition, residential segregation, and the welfare state.</p>",
#   "SSR_COMPONENT_NAME": "Seminar",
#   "Description": "?p?Deals with causes and possible cures for economic inequality, including skill differences, discrimination, immigration, household composition, residential segregation, and the welfare state.?/p?",
#   "EFFDT": "2017-08-16-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": [
#     "AAAS",
#     "SOCL"
#   ],
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=SOCIOL&catnbr=%20296B&classsection=&classnbr=&crseid=112354&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "SOCIOL 296B0012192",
#   "Removed": false,
#   "HU_COURSE_PREQ": "Offered jointly with the Kennedy School as SUP 922. Offered every other year as Gov 2340b.",
#   "Name": "Proseminar on Inequality and Social Policy II",
#   "ACAD_ORG_PRIMARY_ORG": "SOCL",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "Instructor Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>Deals with causes and possible cures for economic inequality, including skill differences, discrimination, immigration, household composition, residential segregation, and the welfare state.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"SOCI\" num=\" 296B\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "SOCSCI",
#   "SearchKey": "4I9Ta5DpMhVZya4AeGo0Od5bu5A=",
#   "CATALOG_NBR": "296B",
#   "CRSE_ID": "112354",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "Primarily for Graduate Students",
#   "IS_SCL_DESCR100": "Proseminar on Inequality and Social Policy II",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Seminar",
#   "Subject": "SOCIOL"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x10744da28>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Economics",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-156356/",
#   "Title": "The Financial System and the Central Bank",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "Economics",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "Y",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "Economics 1723 or 1745, or instructor's permission.",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "Economics",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LDD": "Social Sciences",
#   "LinkURL": "http://ses.my.harvard.edu:80subject=ECON&catnbr=1759&classsection=&classnbr=&crseid=156356&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>This course analyzes the modern financial system. Topics include: (i) the behavior of various types of intermediaries (e.g., banks, broker-dealers, mutual funds, hedge funds); (ii) key elements of the system's plumbing and infrastructure; (iii) sources of systemic risk; and (iv) the multiple roles of the central bank as monetary policymaker, lender of last resort, and regulator.</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?This course analyzes the modern financial system. Topics include: (i) the behavior of various types of intermediaries (e.g., banks, broker-dealers, mutual funds, hedge funds); (ii) key elements of",
#   "EFFDT": "2017-08-15-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": "ECON",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=ECON&catnbr=1759&classsection=&classnbr=&crseid=156356&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "ECON17590012192",
#   "Removed": false,
#   "Name": "The Financial System and the Central Bank",
#   "ACAD_ORG_PRIMARY_ORG": "ECON",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>This course analyzes the modern financial system. Topics include: (i) the behavior of various types of intermediaries (e.g., banks, broker-dealers, mutual funds, hedge funds); (ii) key elements of the system's plumbing and infrastructure; (iii) sources of systemic risk; and (iv) the multiple roles of the central bank as monetary policymaker, lender of last resort, and regulator.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"ECON\" num=\" 1759\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "SOCSCI",
#   "SearchKey": "r0RQe5qdNP5Eg0lU7nrcQSfG6ZA=",
#   "CATALOG_NBR": "1759",
#   "CRSE_ID": "156356",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "The Financial System and the Central Bank",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "ECON"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x10752a290>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Uyghur",
#   "LAST_NAME": "Elliott",
#   "Title": "Elementary Uyghur",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": [
#     "Russia, E Europe, Central Asia",
#     "East Asian Langs & Civ"
#   ],
#   "IS_SCL_DESCR_IS_SCL_DESCRL": "Mark Elliott",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "N",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "East Asian Langs & Civ",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=UYGHUR&catnbr=%20%20%20%20B&classsection=&classnbr=&crseid=124107&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>Continuation of Uyghur A. Completion of basic Uyghur grammar, listening and speaking practice with the aid of audio-visual materials, selected readings from Uyghur literature and academic prose.</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?Continuation of Uyghur A. Completion of basic Uyghur grammar, listening and speaking practice with the aid of audio-visual materials, selected readings from Uyghur literature and academic",
#   "EFFDT": "2017-08-15-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": [
#     "REECA",
#     "EALC"
#   ],
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=UYGHUR&catnbr=%20%20%20%20B&classsection=&classnbr=&crseid=124107&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "UYGHUR B0012192",
#   "Removed": false,
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-124107/",
#   "DESCRLONG_DETAILS": [
#     {
#       "Name": "Mark Elliott",
#       "URL": "",
#       "Photo": "",
#       "EMPLID": "rb8zCDUancrns2Ez4V8HKQ==",
#       "Key": "Mark Elliott",
#       "Email": ""
#     }
#   ],
#   "Name": "Elementary Uyghur",
#   "ACAD_ORG_PRIMARY_ORG": "EALC",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>Continuation of Uyghur A. Completion of basic Uyghur grammar, listening and speaking practice with the aid of audio-visual materials, selected readings from Uyghur literature and academic prose.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"EALC\" num=\"UYGH B\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "ARTS-HUM",
#   "SearchKey": "lc_R_nql/hJ2k9BNYSxqToKpha0=",
#   "CATALOG_NBR": "B",
#   "CRSE_ID": "124107",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "Elementary Uyghur",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "UYGHUR"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x107551758>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Anthropology",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-204020/",
#   "Title": "Revolutionary Violence: An Anthropology of a Concept",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "Anthropology",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "N",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "Anthropology",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LDD": "Social Sciences",
#   "LinkURL": "http://ses.my.harvard.edu:80subject=ANTHRO&catnbr=1715&classsection=&classnbr=&crseid=204020&strm=2198?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>The concept of revolution has been central to political philosophy from its inception. This centrality derives from its threat to disrupt political order and to destroy the very structures it seeks to inaugurate. This seminar is motivated by the question of revolution and revolutionary violence &ndash; its forms, provocations, and temporalities. We will read texts in political theory &ndash; from canonical European liberal thought to Haitian and Algerian anti-colonial revolt &ndash; alongside an</p>",
#   "SSR_COMPONENT_NAME": "Seminar",
#   "Description": "?p?The concept of revolution has been central to political philosophy from its inception. This centrality derives from its threat to disrupt political order and to destroy the very structures it seeks",
#   "EFFDT": "2017-08-15-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Fall",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": "ANTH",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=ANTHRO&catnbr=1715&classsection=&classnbr=&crseid=204020&strm=2198?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "ANTHRO17150012198",
#   "Removed": false,
#   "Name": "Revolutionary Violence: An Anthropology of a Concept",
#   "ACAD_ORG_PRIMARY_ORG": "ANTH",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>The concept of revolution has been central to political philosophy from its inception. This centrality derives from its threat to disrupt political order and to destroy the very structures it seeks to inaugurate. This seminar is motivated by the question of revolution and revolutionary violence &ndash; its forms, provocations, and temporalities. We will read texts in political theory &ndash; from canonical European liberal thought to Haitian and Algerian anti-colonial revolt &ndash; alongside anthropological interrogations of their limits, particularly as they become evident from the spaces of the medical and psychiatric clinic. Foregrounding figurations of the state and historical change, we will attend to notions of time and how they underwrite divergent representations of progress, order, justice, and violence. We will engage in close readings of philosophical texts on their own terms and will then put to work an anthropological mode of reading to bring out the elisions performed by the movement of theory abstracted from lived experience. Alongside theoretical texts, we will consider anthropological accounts of violence, (post)colonial subjectivity, and the contemporary poor by Biehl, Comaroff and Comaroff, Farmer, and Good. With the ethnographic as conceptual pivot, we will turn from canonical works in political theory &ndash; Hobbes, Kant, Hegel, Weber &ndash; to counterhegemonic traditions arising from Marxism, anti-colonialism and black radical thought, political psychiatry, and deconstruction. Readings may include texts by Marx, Sorel, Schmitt, Benjamin, Fanon, Sartre, Arendt, Guattari, Derrida, Mbembe, Chakrabarty, and Berlant</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"ANTH\" num=\" 1715\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "SOCSCI",
#   "SearchKey": "XmOu5oyVSFJ9I_wW8WB7zmGfmOc=",
#   "CATALOG_NBR": "1715",
#   "CRSE_ID": "204020",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "Revolutionary Violence: An Anthropology of a Concept",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Seminar",
#   "Subject": "ANTHRO"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x1074f6e60>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "History of Science",
#   "LAST_NAME": "Lemov",
#   "Title": "History of Anthropology",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "History of Science",
#   "IS_SCL_DESCR_IS_SCL_DESCRL": "Rebecca Lemov",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "N",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "History of Science",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=HISTSCI&catnbr=%20159&classsection=&classnbr=&crseid=156895&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>This conference course looks at the long history of anthropological inquiry. We will begin with early modern \"Curiosity Cabinets\" that sequestered anthropological materials alongside the miraculous, marvelous, and mundane. We then turn to the age of exploration with its first-hand encounters between high-seas explorers or cross-continental travelers and tribal or non-Western groups sometimes known as \"natives.\" After some attention to anthropological zoos and world's fairs, we will discuss the d</p>",
#   "SSR_COMPONENT_NAME": "Seminar",
#   "Description": "?p?This conference course looks at the long history of anthropological inquiry. We will begin with early modern \"Curiosity Cabinets\" that sequestered anthropological materials alongside the",
#   "EFFDT": "2017-08-15-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": "HSCI",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=HISTSCI&catnbr=%20159&classsection=&classnbr=&crseid=156895&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "HISTSCI 1590012192",
#   "Removed": false,
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-156895/",
#   "DESCRLONG_DETAILS": [
#     {
#       "Name": "Rebecca Lemov",
#       "URL": "",
#       "Photo": "",
#       "EMPLID": "HHZYomUrGHz33zmERX7nuA==",
#       "Key": "Rebecca Lemov",
#       "Email": ""
#     }
#   ],
#   "Name": "History of Anthropology",
#   "ACAD_ORG_PRIMARY_ORG": "HSCI",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>This conference course looks at the long history of anthropological inquiry. We will begin with early modern \"Curiosity Cabinets\" that sequestered anthropological materials alongside the miraculous, marvelous, and mundane. We then turn to the age of exploration with its first-hand encounters between high-seas explorers or cross-continental travelers and tribal or non-Western groups sometimes known as \"natives.\" After some attention to anthropological zoos and world's fairs, we will discuss the dawn of anthropology's professional golden age in the twentieth century; the arrival of epistemological and political crises during the 1960s, 1970s, and 1980s; and finally the current day's ontological turn, circling back to the interpretive and epistemological goals that have often animated the field.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"HSCI\" num=\" 159\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "SOCSCI",
#   "SearchKey": "qxASbpNblq6qJJ21IuGyVMv1ohc=",
#   "CATALOG_NBR": "159",
#   "CRSE_ID": "156895",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "History of Anthropology",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Seminar",
#   "Subject": "HISTSCI"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x1074f6c68>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "History",
#   "LAST_NAME": "Angelov",
#   "Title": "Byzantine Civilization",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": [
#     "Medieval Studies",
#     "Classics, The",
#     "General Education",
#     "History"
#   ],
#   "IS_SCL_DESCR_IS_SCL_DESCRL": "Dimiter Angelov",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "N",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "History",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LDD": "Social Sciences",
#   "LinkURL": "http://ses.my.harvard.edu:80subject=HIST&catnbr=1035&classsection=&classnbr=&crseid=108059&strm=2192?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>The Byzantine (Eastern Roman) Empire outlived the fall of Rome by a thousand years. In what ways did Byzantium preserve the institutions and politics of imperial Rome? In what ways was it a medieval civilization? How did Byzantium's professional armies, able diplomats, and brilliant intellectuals ensure its survival and renewed expansion? This course traces the story of the Byzantine Empire between c. 600 and 1453, setting it in the context of medieval and world history.</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?The Byzantine (Eastern Roman) Empire outlived the fall of Rome by a thousand years. In what ways did Byzantium preserve the institutions and politics of imperial Rome? In what ways was it a",
#   "EFFDT": "2017-08-15-12.00.00.000000",
#   "IS_SCL_MEETING_PAT_HU_LIKELY_OFFERED": "2019 Spring",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": [
#     "MDST",
#     "CLAS",
#     "GENED",
#     "HIST"
#   ],
#   "CombinedSectionClass": "hide",
#   "ACAD_ORG_PRIMARY_ORG": "HIST",
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=HIST&catnbr=1035&classsection=&classnbr=&crseid=108059&strm=2192?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "HIST10350012192",
#   "Removed": false,
#   "HU_COURSE_PREQ": "This course, when taken for a letter grade, meets the General Education requirement for Societies of the World. This course fulfills the requirement that one of the eight General Education courses also engage substantially with Study of the Past.",
#   "DESCRLONG_DETAILS": [
#     {
#       "Name": "Dimiter Angelov",
#       "URL": "",
#       "Photo": "",
#       "EMPLID": "r21uuIuTWFqgmOCOuPjn5g==",
#       "Key": "Dimiter Angelov",
#       "Email": ""
#     }
#   ],
#   "Name": "Byzantine Civilization",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_GE": [
#     "Societies of the World",
#     "Study of the Past"
#   ],
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>The Byzantine (Eastern Roman) Empire outlived the fall of Rome by a thousand years. In what ways did Byzantium preserve the institutions and politics of imperial Rome? In what ways was it a medieval civilization? How did Byzantium's professional armies, able diplomats, and brilliant intellectuals ensure its survival and renewed expansion? This course traces the story of the Byzantine Empire between c. 600 and 1453, setting it in the context of medieval and world history.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"HIST\" num=\" 1035\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "SOCSCI",
#   "SearchKey": "iqOkIx9KTdwmGrD0WpE2DWPE75M=",
#   "CATALOG_NBR": "1035",
#   "CRSE_ID": "108059",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-108059/",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "Byzantine Civilization",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "ClassStartDt": null,
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "HIST"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x107670248>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR100_HU_SCL_ATTR_XREG": "Available for Harvard Cross Registration",
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Korean",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/colgsas-115518/",
#   "Title": "Readings in Cultural Studies",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "East Asian Langs & Civ",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "Y",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Faculty of Arts & Sciences",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "Korean 140b or equivalent.",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "East Asian Langs & Civ",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LDD": "None",
#   "LinkURL": "http://ses.my.harvard.edu:80subject=KOREAN&catnbr=%20150B&classsection=&classnbr=&crseid=115518&strm=?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p>Continuation of Korean 150a.</p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "?p?Continuation of Korean 150a.?/p?",
#   "EFFDT": "2016-08-15-12.00.00.000000",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Faculty of Arts & Sciences",
#   "ACAD_ORG": "EALC",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=KOREAN&catnbr=%20150B&classsection=&classnbr=&crseid=115518&strm=?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "KOREAN 150B001",
#   "Removed": false,
#   "Name": "Readings in Cultural Studies",
#   "ACAD_ORG_PRIMARY_ORG": "EALC",
#   "GRADING_BASIS": "LG",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "FAS Letter Graded",
#   "ACAD_CAREER": "FAS",
#   "IS_SCL_DESCR": "<p>Continuation of Korean 150a.</p>",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"EALC\" num=\"KORE 150B\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "ARTS-HUM",
#   "SearchKey": "e3xPk/3Ly07stIgcsHmXJ3VGkMQ=",
#   "CATALOG_NBR": "150B",
#   "CRSE_ID": "115518",
#   "IS_SCL_DESCR100_HU_SCL_ATTR_LEVL": "For Undergraduate and Graduate Students",
#   "IS_SCL_DESCR100": "Readings in Cultural Studies",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "UnitsDisplay": "4",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "KOREAN"
# }
# (<type 'exceptions.TypeError'>, TypeError('expected string or buffer',), <traceback object at 0x107670170>)
#   File "<ipython-input-40-0078e727137e>", line 6, in <module>
#     mapper.map(raw, to=parsed)
#   File "<string>", line 48, in map
#   File "<ipython-input-37-8ce01abfa325>", line 80, in mapSessions
#     return {'sessions': [mapSession((start, end, days, locNameOrNames, locNumber, latitude, longitude))]}
#   File "<ipython-input-37-8ce01abfa325>", line 45, in mapSession
#     seshSet('days', mapDays(days))
#   File "<ipython-input-37-8ce01abfa325>", line 17, in mapDays
#     return daysReplace.sub(days).split(' ')
#   File "<string>", line 8, in sub
# {
#   "IS_SCL_DESCR_IS_SCL_DESCRD": "Reading and Research",
#   "URL_URLNAME": "https://locator.tlt.harvard.edu/course/hks-170845/",
#   "Title": "Reading and Research: Swanee Hunt",
#   "IS_SCL_DESCR_IS_SCL_DESCRM": "HKS Government",
#   "HU_UNITS_MAX": "4",
#   "HU_RECPREP_FLAG": "N",
#   "IS_SCL_DESCR_IS_SCL_DESCRI": "Harvard Kennedy School",
#   "IS_SCL_DESCR_IS_SCL_DESCRH": "Not Offered",
#   "RecPrepDescr": "",
#   "IS_SCL_DESCR_IS_SCL_DESCRJ": "HKS Government",
#   "IS_SCL_DESCRSHORT_HU_CONSENT": "No Consent",
#   "Score": 4,
#   "LinkURL": "http://ses.my.harvard.edu:80subject=RAR&catnbr=%20377&classsection=&classnbr=&crseid=170845&strm=?SESLanguageCd=ENG",
#   "IS_SCL_DESCR_HU_SCL_DESCRNOHTML": "<p></p>",
#   "SSR_COMPONENT_NAME": "Lecture",
#   "Description": "",
#   "EFFDT": "2016-08-30-12.00.00.000000",
#   "IS_SCL_DESCR_IS_SCL_DESCRB": "Harvard Kennedy School",
#   "ACAD_ORG": "GOV",
#   "CombinedSectionClass": "hide",
#   "ClassStartDt": null,
#   "Sponsored": false,
#   "ClassEndDt": null,
#   "Key": "http://ses.my.harvard.edu:80subject=RAR&catnbr=%20377&classsection=&classnbr=&crseid=170845&strm=?SESLanguageCd=ENG",
#   "HU_UNITS_MIN": "4",
#   "IS_SCL_SUBJ_CAT": "RAR 377001",
#   "Removed": false,
#   "Name": "Reading and Research: Swanee Hunt",
#   "ACAD_ORG_PRIMARY_ORG": "GOV",
#   "GRADING_BASIS": "SUS",
#   "Modified": "2017-08-18-00.00.00.000000",
#   "IS_SCL_DESCR_HU_CONSENT": "No Special Consent Required",
#   "IS_SCL_DESCR100_HU_SCL_GRADE_BASIS": "HKS Satisfactory/Unsatisfactory",
#   "ACAD_CAREER": "HKS",
#   "SecondaryComponentsClass": "hide",
#   "COOP_LINK": "<?xml version=\"1.0\" encoding=\"UTF-8\"?><textbookorder><courses><course dept=\"\" num=\"377\" sect=\"LL\" term=\"Wot\" /></courses></textbookorder>",
#   "PARENT_NODE_NAME": "HKS",
#   "SearchKey": "ZPk2xvPaq2KTDne0BOJpxvhSa4A=",
#   "CATALOG_NBR": "377",
#   "CRSE_ID": "170845",
#   "UnitsDisplay": "4",
#   "IS_SCL_DESCR100": "Reading and Research: Swanee Hunt",
#   "CourseReqDescr": "NA",
#   "STRM": "BRKT",
#   "ShopCartOpenCheck": "N",
#   "SSR_COMPONENTDESCR": "Lecture",
#   "Subject": "RAR"
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-0078e727137e> in <module>()
#      12     print_tb(sys.exc_info()[2], file=sys.stdout)
#      13     print json.dumps(raw, indent=2)
# ---> 14     sleep(5)
#
# KeyboardInterrupt:
